# %%
import pandas as pd

train_data = pd.read_csv(r'E:\Develop\python\NLP\howls_nlp\Chatbot\자료\results\Q&A.csv', encoding = 'cp949')
print(train_data.keys())
lemma = list(train_data["LEMMA"][3023:])
ans = list(train_data['ANSWER'][3023:])
ans = [str(i)[2:-2] for i in ans]
data_pair = [[lemma[i], ans[i]] for i in range(len(lemma))]
print(data_pair[1][1])
# Out:
# Index(['QUESTION', 'ANSWER', 'TAGSET', 'LEMMA'], dtype='object')
# 미네르바는 교양필수과목이기 때문에 타교양으로 재수강 연결을 할 수 없습니다 (동일과목으로만 재수강 가능)

# %%
import random
import torch
import torch.nn as nn
from torch import optim

# %%
torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
SOS_token = 0
EOS_token = 1

# %%
class Vocab:
  def __init__(self):
    self.vocab2index = {"<SOS>": SOS_token, "<EOS>": EOS_token}
    self.index2vocab = {SOS_token: "<SOS>", EOS_token: "<EOS>"}
    self.vocab_count = {}
    self.n_vocab = len(self.vocab2index)
  
  def add_vocab(self, sentence):
    for word in str(sentence).split(" "):
      if word not in self.vocab2index:
        self.vocab2index[word] = self.n_vocab
        self.vocab_count[word] = 1
        self.index2vocab[self.n_vocab] = word
        self.n_vocab += 1
      else:
        self.vocab_count[word] += 1

# %%
#길이 filtering
def filter_pair(pair, source_max_length, target_max_length):
  return len(pair[0].split(' ')) < source_max_length and len(pair[1].split(' ')) < target_max_length

# %%
source_vocab = Vocab()
target_vocab = Vocab()
def preprocess(corpus, source_max_length, target_max_length):
  print('reading corpus...')
  pairs = []
  
  #for line in corpus:
    #pairs.append([s for s in line.strip().lower().split('\t')])
  #print('Read {} sentence pairs'.format(len(pairs)))

  #pairs = [pair for pair in pairs if filter_pair(pair, source_max_length, target_max_length)]
  #print('Trimed to {} sentence pairs'.format(len(pairs)))
  pairs = corpus

  print('Counting Words...')
  for pair in pairs:
    source_vocab.add_vocab(pair[0])
    target_vocab.add_vocab(pair[1])
  print('source vocab size = ', source_vocab.n_vocab)
  print('target vocab size = ', target_vocab.n_vocab)

  return pairs, source_vocab, target_vocab

# %%
def concat_vocab(voca1, sentence):
  voca1.add_vocab(sentence)
  return voca1

# %%
class Encoder(nn.Module):
  def __init__(self, input_size, hidden_size):
    super(Encoder, self).__init__()
    self.hidden_size = hidden_size
    self.embedding = nn.Embedding(input_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size)

  def forward(self, x, hidden):
    x = self.embedding(x).view(1, 1, -1)
    x, hidden = self.gru(x, hidden)
    return x, hidden

# %%
class Decoder(nn.Module):
  def __init__(self, hidden_size, output_size):
    super(Decoder, self).__init__()
    self.hidden_size = hidden_size
    self.embedding = nn.Embedding(output_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size)
    self.out = nn.Linear(hidden_size, output_size)
    self.softmax = nn.LogSoftmax(dim = 1)

  def forward(self, x, hidden):
    x = self.embedding(x).view(1, 1, -1)
    x, hidden = self.gru(x, hidden)
    x = self.softmax(self.out(x[0]))
    return x, hidden

# %%
#sentence -> index tensor(텐서로 변환)
def tensorize(vocab, sentence):
  indexes = [vocab.vocab2index[word] for word in str(sentence).split(' ')]
  indexes.append(vocab.vocab2index["<EOS>"])
  return torch.Tensor(indexes).long().to(device).view(-1, 1)

# %%
#train seq2seq
def train(pairs, source_vocab, target_vocab, encoder, decoder, n_iter,
          print_every = 1000, learning_rate = 0.01):
  loss_total = 0

  encoder_optimizer = optim.Adam(encoder.parameters(), lr = learning_rate)
  decoder_optimizer = optim.Adam(decoder.parameters(), lr = learning_rate)

  training_batch = [random.choice(pairs) for _ in range(n_iter)]
  training_source = [tensorize(source_vocab, pair[0]) for pair in training_batch]
  training_target = [tensorize(target_vocab, pair[1]) for pair in training_batch]

  criterion = nn.CrossEntropyLoss()

  for i in range(1, n_iter + 1):
    source_tensor = training_source[i-1]
    target_tensor = training_target[i-1]

    encoder_hidden = torch.zeros([1, 1, encoder.hidden_size]).to(device)

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    source_length = source_tensor.size(0)
    target_length = target_tensor.size(0)

    loss = 0

    for enc_input in range(source_length):
      _, encoder_hidden = encoder(source_tensor[enc_input], encoder_hidden)

    decoder_input = torch.Tensor([[SOS_token]]).long().to(device)
    decoder_hidden = encoder_hidden

    for di in range(target_length):
      decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
      loss += criterion(decoder_output, target_tensor[di])
      decoder_input = target_tensor[di] #teacher forcing
    #teacher forcing = output값을 다음의 인코더로 넣어줄 수 있지만
    #연산량을 줄이기 위해 정답을 넣어준다. 각각 장단점이 있기에
    #티처 포싱의 단점을 막기 위해 랜덤으로 x%만 티처 포싱을 진행한다.

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    loss_iter = loss.item() / target_length
    loss_total += loss_iter

    if i % print_every == 0:
      loss_avg = loss_total / print_every
      loss_total = 0
      print('[{} - {}%] loss = {:05.4f}'.format(i, i/n_iter*100, loss_avg))

# %%
def evaluate(pairs, source_vocab, target_vocab, encoder, decoder, target_max_length):
  for pair in pairs:
    print('>', pair[0])
    print('=', pair[1])
    source_tensor = tensorize(source_vocab, pair[0])
    source_length = source_tensor.size()[0]
    encoder_hidden = torch.zeros([1, 1, encoder.hidden_size]).to(device)

    for ei in range(source_length):
      _, encoder_hidden = encoder(source_tensor[ei], encoder_hidden)

    decoder_input = torch.Tensor([[SOS_token]]).long().to(device)
    decoder_hidden = encoder_hidden
    decoded_words = []

    for di in range(target_max_length):
      decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
      _, top_index = decoder_output.data.topk(1)
      if top_index.item() == EOS_token:
        decoded_words.append('<EOS>')
        break
      else:
        decoded_words.append(target_vocab.index2vocab[top_index.item()])
      
      decoder_input = top_index.squeeze().detach()

    predicted_words = decoded_words
    predict_sentence = " ".join(predicted_words)
    print('<', predict_sentence)
    print("")

# %%
SOURCE_MAX_LENGTH = 100
TARGET_MAX_LENGTH = 100

# %%
load_pairs, load_source_vocab, load_target_vocab = preprocess(data_pair, SOURCE_MAX_LENGTH,
                                                              TARGET_MAX_LENGTH)
print(load_pairs)
# Out:
# 업이면 당연히 같이여'], ['전과 이중전공 신청 전과 선택 이중전공 신청 아니', "가능.', '아진짜요?다행이다ㅠㅠㅠㅠ감사합니다!! 근데 이런 건 어디서 확인할 수 있나요..ㅠ', '학종지에 물어보심 됩니다.', '학종지가 뭔지 여쭤봐도 될까요..? 새내기라 모르겠어요 ㅠㅠ', '학사종합지원센터요.  학교에서 학사관련 담당하는 부서', '감사합니다!"], ['이중전공 대하 고민 머리 터지 학기 학점 35 국제 학부 국제 통상 정치 외교 가망 국제 통상 시험 영어 수학 나오 정치 외교 면접 정치 시사 관하 질문 나오 준비 모르 신문 사설 국제 배우 국제 통상 경제인 나중 영사 시험 생각 도움 선배', '3.5였는데 2학기때 학점 잘받으면 되지않을까'], ['이중전공 경제 통계 전공 언어 고등학교 수학 좋아하', "설캠에서 집이 가깝고 학점이 높으시면 경제하시고', '글캠에서 집이 가깝고 학점이 좀 낮으시면 통계하세용', '감사합니다!!"], ['나중 복전 이중전공 올리', "복전에서 이중은 무슨말이얌?', '말 그대로 처음엔 복전을 했다가 나중에 이중전공 시험을 쳐서 이중으로 올리는 거요’', '부전공말하는거지..?', '억 네', '이중변경공지에 티오 직접봐', '헉 그거는 국통 홈페이지에서 확인 가능한가요? 이중시험 공고만 봤더니...', '학사공지 이중변경공지 첨부파일', '앗 감사합니다!', '별로 안나는데 그렇게 메리트가 잇을까도싶궁..1전공이 상경이라', '음 저는 1전공이 언어라서욥... 상경이시면 안하셔도 되겠네요"], ['새내기 학점 관리 설캠 이중전공 못하 설캠 부전공 나중 이중전공 바꾸 힘들', "베트남어 빼고는 미달인데... 설캠생활하고 싶으면 그냥 아무 언어과 지원하시면 걍 붙어요', '아그렇구나 알려주셔서 감사해요 !', '음 근데 설캠 왔다갔다하시기 힘드시지 않아요..? 거리도 있고 힘드실 것 같은데 언어과라면 글캠에도 통번역 있으니까 그쪽 알아봐도 될 것 같은데....', '제가 언어전공이라서 언어말고 다른 전공을 알아보는 중이였습니다 ㅎㅎ 네 말씀대로 더 알아보고 신중히 결정해야 될 것 같아요 !', '조언 감사해용:)', '단순히 서울캠 생활을 하고 싶으신 거라면 비추입니다.....', '교통편 때문에 힘드신거세요?ㅠㅠ', '네 일단 이게 차지하는 게 엄청 커요.... 그냥 왔다갔다 한번만 해도 지치고 자취방 돌아오면 아무 생각도 안 나고 씻고 자고 싶은 생각만 납니다ㅠㅠ 그리고 저는 알바도 같이 했었는데 진짜 죽는 줄 알았어요ㅠㅠ', '아그렇구나ㅠㅠ 솔직한 말씀 감사합니당', '참고해서 정말 신중히 결정해야 될 것 같아요ㅠㅠ 혹시 무슨 과이셨는지 얘기 더 들어봐도 괜찮을까요? 괜찮으시면 쪽지하고 싶어요 !"], ['이중전공 신청 전과 신청 만약 이중전공 신청 전공 과로 전과 신청 가능 가정 성공 이중전공 어떻', "삭제된 댓글입니다.', '감사합니다!"], ['이중전공 문화콘텐츠 스통뭐', "차라리 스통!', 'ㅠㅠㅠㅠㅠㅠㅠ왜여ㅠㅠㅠㅠㅠㅠㅠㅠ', '1전공이 뭔데요?"], ['이중전공 고민 17 스페인어 이중전공 중외 고민', '영어 좀 하면 국통'], ['전과 생각 전과 이중전공 이중전공 전과 거죠전과 따르 이중전공 달라지 어떡하', "삭제된 댓글입니다.', '아ㅏㅋㅋㅋㅋㅋ감사합니다ㅎ힣ㅎ', '저도 궁금해요 알려주세요ㅠㅠㅠ"], ['이중전공 지망 지망 지망 떨어지 자동 지망 배정 만약 지망 떨어지 이중전공', "당연히 2지망도 떨어지지요  안그럼 다 2지망에 좋은거쓰지 나중에 변경기간에 빈자리신청', '아 그럼 1지망이나 2지망중에 애초에 붙을때는 한개만 붙는건가요?', '1지망으로 심사하고 떨어진 사람대상으로 2지망배정하는데 1지망배정하고 자리가 남은 학과만 배정가능해요"], ['그러 이중전공 부전공 차이점 어디 나오', '수강편람'], ['이중전공 지망 지망 지망', '1지망 배정되면 아예 2지망은 배정이라는 개념이 없단다. 아예 고려대상이 아니얌'], ['이중전공 경영 경제 고민 장단점 알리 사례', "경영 팀플이 많다 수강신청이 매우 하드코어하다 경제 학점따기어렵다 개인적으로 느끼기에 강의력좋은 교수님이 매애우 드물다 에이를 30퍼 안채워주시는교수님이 꽤 많다', '경제는 이중수강중이니 추가로 물어보실거쪽지하세요"], ['수학 경영 경제 이중전공 이중전공 계열', '어문 아니면 행정 이런거 많이 하지 않나'], ['학년 이중전공 신청 언제 불안', "http://builder.hufs.ac.kr/user/indexSub.action?codyMenuSeq=37080&siteId=hufs&menuType=T&uId=4&sortChar=AB&linkUrl=04_0202.html&mainFrame=right&dum=dum&boardId=17221&page=1&command=view&boardSeq=97538788', '감사합니다!♥?"], ['경영 이중전공 필요 토익 750 아니 그것', '그거만 넘으면 됨 경영학원론 공부하셈요'], ['경영학과 이중전공 시험 어렵', "저 준비 한 3일좀 바짝했는데 붙었어용 근데 이것도 사바사라..책 잘 보시면 안어려울거에요', '토익 몇점컷임?"], ['학기 학점 나오 어떻 이중전공 조언 부탁 드리', "얼마나 안나왔는지 얘기좀', '2점대 후반입니다...', '부전공을 하다가 이중으로 올리던가, 2학기 성적 4점대 받던가..토익은 봤나?', '토익 점수는 괜찮아요!! 800점대 후반이에요', '중간고사로 봤을 때 4점대 가능?', '차라리 경제는 어때?', '경제가 더 높은데', '중간고사 전공 하나 빼고는 다 에쁠일 것 같아요', '경제는 제가 수학 싫어해서ㅠ', '잉? 국통이든 경제든 수학하는데? 다만 국통은 영어로 하고 경제는 한국말로 한다는 게 차이지만..근데 경제는 80명 정도가 정원이라 이중도 120정도가 열리는데 국통은 40인가? 그래서 60~70밖에 안열릴 거 같아..1전공은 뭐야?', '1전공은 언어요 근데 제가 국통을 하고 싶은 이유가 국제적인 뭔가를 하고 싶어서거든요.... 경제는 그런 부분은 딱히 없는 거 같아서', '근데 보통 상경은 3점 후반이 안전으로 알고 있는데 일단 신청은 해보는게 좋은 것 같다..소수어야? 메이저언어야? 나도 궁금한게 하나 있어서', '전 소수어요', '소수어에는 그 지역 살다온 학생들이 많은가??', '아뇨 별로 없어요. 가끔 한둘 정도? 학점 킬러분들은 대부분 다 고학번 선배들이시거나 칠쁠일도 다녀오시고 그런 분들이에요', '삭제된 댓글입니다.', '아뇨 그런 거 말고 조언 부탁드린 건데요', '이중변경하던가 부전하다 이중으로 올리던가', '부전하다 이중으로 올리는 게 더 쉬운가욮', '둘다 티오가 나야 하는거지 똑같음', '친구 2점대 후반 국통시험 거의 만점받고 지금국통이중', '만점 받으면 가능한가요..?', '삭제된 댓글입니다.', '이 정도는 아셔야 하는 거 아닌가요...', '국통 시험이 따로 있나요??', '네', '그런건 어디서 확인하나요?', '국통 학과 홈페이지요', '합격하셨나요??ㅜㅜ"], ['경영 전공 이중전공 사회 과학 계열 어문 낫겟죠 베이스 하나 사회과학 계열 어문 계열', '외대인데 외국어!'], ['이중전공 어떻 커리 도움', ''], ['이중전공 커리 전공 사람 커리 다르 이중전공 어디 확인', '전필은 같아여 학과홈페이지 참고'], ['제가 문과 예전 공대 관심 가지 공대 이중전공 변경 추천 전공 공대 이중전공 인원', "컴공입니당', '워낙 공부가 빡쎄서 티오는 남습니다... 컴공이 가장 쓸모는 많겠죠"], ['미컴 행정 정외 이중전공 얼마 정도', "미컴은 4이상 행정정외는 3중후반?', '오오... 알려줘서 고마웡~!~!"], ['경영 이중전공 외대 문과 살리 무역 해외 영업 직무 생각 공부 경영 이중전공 이쪽 메리트 기업 대하 아니 100 프로 연관 의미 공부 의문 아시 경영 학점 관리 어렵 시간 효율 38 정도 유지 힘들 그렇 부전공 내리 전공 공부 러시아 부전공 기업 쳐주 이중전공 러시아어 전공 머리 선배 조언 부탁 드리', '경영쪽 전공자 우대하는 기업이 생각보다 많아요...! 해외영업쪽이면 경영이 중요할텐데... 실무를 아니고서야 학교에서 배우는 모 ...

# %%
enc_hidden_size = 30
dec_hidden_size = enc_hidden_size
enc = Encoder(load_source_vocab.n_vocab, enc_hidden_size).to(device)
dec = Decoder(dec_hidden_size, load_target_vocab.n_vocab).to(device)

# %%
train(load_pairs, load_source_vocab, load_target_vocab, enc, dec, 50000, print_every = 1000)
# Out:
# [1000 - 2.0%] loss = 8.3413
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c2c74d304462> in <module>
# ----> 1 train(load_pairs, load_source_vocab, load_target_vocab, enc, dec, 50000, print_every = 1000)
#
# <ipython-input-12-3979a6a2bb37> in train(pairs, source_vocab, target_vocab, encoder, decoder, n_iter, print_every, learning_rate)
#      41     #티처 포싱의 단점을 막기 위해 랜덤으로 x%만 티처 포싱을 진행한다.
#      42
# ---> 43     loss.backward()
#      44
#      45     encoder_optimizer.step()
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
evaluate(load_pairs, load_source_vocab, load_target_vocab, enc, dec, TARGET_MAX_LENGTH)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# = 횟수 상의 제한은 없습니다~
# < 네 가능합니다 <EOS>
#
# > 질문 드리 학기 18 학점 학기 20 학점 수강 학점 짜리 학년 사실 36 학점 채우 수강편람 학년 34 학점 미만 학기 기말고사 과목 재수강 과목 재수강 학기 이수 학점 줄어들 개념 재수강 인하 학년 이수 학점 34 학점 미만 경우 어떻 처리 경우 문제 감사
# = 학년별로 이수해야할 학점이 있긴 한데 사실상 형식적인 겁니다 1학년 성적이 모두 F라서 이수학점이 없든 재수강으로 당시 이수한 학점이 조금씩 차감되든 전혀 상관 없으며, 졸업전까지 모든 졸업학점을 다 채우시면 됩니다~', '만일 재수강으로 1학년 당시 이수학점이 34학점 미만이 되어 문제가 생긴다면 저도 졸업할 수 없어요 ㅋㅋ ㅜ', '으앙ㅋㅋㅋㅋ그렇구나 글을 두서없이 써서 조교님이 알아들으실 수 있을까 했는데  역시 개떡같이 말해도 찰떡같이 알아들어주시는군여?? 이번에도 답변 감사합니당
# < 네 그렇게 됩니다 <EOS>
#
# > 학기 이중전공 시험 떨어지 경영 후기 이중
# = 이중전공 신청, 즉 재학생의 이중전공 변경은 4학년때까지 가능합니다 후기이중으로 올리는 방법도 있긴 한데 그건 별도의 심사과정을 거칩니다(신청자의 졸업이수학점 충족 등) 따라서 현재 이수한 학점, 추가학기 등록 여부를 고려해 계획을 세우시길 바랍니다
# < 이중전공 변경은 있던데 2학년 이후부턴 또는 매학기마다 학년별, 이중전공 변경신청으로만 배정이 가능합니다 <EOS>
#
# > 영어 학과 전과 경영학 돌리 이중전공 가능
# = eicc가 영어학과 내 전공과정이라면 불가능합니다 전과생은 전적학과의 전공을 이중으로 돌릴 수 없거든요', '영어대학 안에 eicc 영어 영미문학 이렇게 세개가 있는데 저 그럼 완전 뷸가한건가요?', '학과 내 전공이 아니라 단과대라면 사정이 다를 것 같네요...전적학과 전공만 아니면 되거든요 이건 학종지에 한번 문의해보셔야 할 듯 합니다..설캠 쪽 세부전공은 저도 잘 몰라서요 ㅜㅜ', '알겠습니다 ㅠㅜ감사합니나!', '가능합니다
# <  <EOS>
#
# > 학년 71 갔다오 다음 해외 인턴쉽 생각 학점 인정
# = 1개 학기 기준으로 칠쁠일은 최대 18학점, 인턴은 최대15학점(전공12) 인정됩니다 단 이건 최대 인정범위이며 학과별로 연수국가나 기관 등을 기준으로 학점을 제한하는 경우도 있습니다 정확한 인정 범위는 해당학과 사무실에 문의바랍니다', '3학년을 마치고 4학년 1학기에 칠쁠일로 가는건 가능합니다 단 4학년 2학기 인턴 파견은 프로그램마다 제한을 두는 경우도 있으니 확인바랍니다
# < 칠플일은 선발은 칠쁠일, 교환 등 대부분의 차원에서 지원하는 장학금이라면 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 여쭈 학년 재학 이중전공 신청 지망 지원 떨어지 지망 포기 전공 부전공 선택 이번 년도 전공 부전공 이중전공 올리 처음 지망 전공 아니 전공 이중전공 지금 전공 수업 경우 전공 이중전공 내년 학기 부전공 신청 기간 변경 학점 채우 이중전공 전공 신청 알리 감사
# = 우선 학생의 경우 '이중전공 변경'을 통해 부전공을 이중으로 올린거니 재학중 1회 변경에 해당됩니다(같은 부전 -> 이중도 변경으로 봄) 따라서 현재는 이중 변경이 불가능한데, 이 경우 원하시는 B전공을 변경 제한이 없는 부전으로 올리신 후 매년 4월 경 7~8학기 재학 상태에서 후기이중전공을 신청하시면 됩니다", '부전으로 올리신 후 -> 돌리신 후', '감사합니다!!
# < 네 그렇게 됩니다 <EOS>
#
# > 학년 11 이중전공 신청 학점 기준 학년 학기 성적 학년 학기 들어가
# = 저도 궁금합니다', '2학기 들어감.', '2학기까지들감', '1학년 2학기까지의 성적을 기준으로 합니다~
# < 네 그렇게 됩니다 <EOS>
#
# > 렉스 11 12 이후 시험 외국어 인증 플렉스로 실외 대체 가능 시험 일정 어디
# = 외국어 인증 역시 플렉스로 대체할 수 있습니다 대한상공회의소 자격평가사업단에서 일정을 확인할 수 있는데 올해는 11월 12일이 마지막으로 되어있네요
# < 네 가능합니다 <EOS>
#
# > 재수강 절대 평가 기준 교수 따르 다르
# = 네 교수님 재량입니다~
# < 네 그렇게 됩니다 <EOS>
#
# > 부전공 이중전공 바꾸 부전공 변경 기간 바꾸 아니 이중전공 변경 기간 바꾸
# = 이중변경', '이중변경 때 하시면 됩니다~', '감사합니다~
# <  <EOS>
#
# > 제가 자선 학점 14 학번 이중전공 자선 필요 학점
# = 그냥 더 들은거임  그냥 자선으로 남음', '졸업학점과 상관없으니 그냥 낭비된 경우라 보심 됩니다 ㅜㅜ
# < 넹', '혹시 어디다 제출하는지 알 수 있을까요???? 찾아봐도 안나와서욥,,,', '그건 겨울계절이 안되는거고 여름계절은 되지않나요? 18-2 복학하면되니깐요', '이번 겨울 계절도 그냥 교직아수를 이수해야 할 수 있는데 없는 것인가요?', '네 혹시 더 물어봐요! 많이 않는다고 되어있습니다 <EOS>
#
# > nan
# = 평점이 낮아지죠 필수과목이면 반드시 재수강해야하고', '평점도 낮아지고 미이수 같이 처리되서 학점 인정도 안됩니다', '학고는아닌가요?', '그 학기 총 평점이 1.75미만이면 학고고  다른거 잘해서 1.75넘으면 학고 아니고
# < 네 그렇게 됩니다 <EOS>
#
# > 수강 과목 계절 학기 재수강 횟수 차감
# = 계절학기 재수강은 차감 안됩니다~
# < 네 가능합니다 <EOS>
#
# > 글캠 소수어과 전공 학년 남자 이중전공 경영학 생각 제가 학년 학기 마치 군대 이중전공 신청 학년 학기 학년 학기 이중전공 이수 학년 학기 마치 군대 경영 중간 끊기 경영 학점 관리 이중전공 신청 학년 학기 부전공 경영 신청 나중 군대 부전공 경영 이중전공 경영 변경 만약 가능 이번 학기 이중전공 신청 필요 기간 부전공 신청 부전공 경영 글캠 마지막 이중전공 신청 이번 학기 토익 점수 필요 질문 두서없
# = 그리고 정말 죄송한데 혹시 이번학기에 이중전공은 신청해서 통과만 시켜놓고 안듣고있다가 나중에 군대 갔다오고 복학하고 나서 이수해도 되는건가요..? 제가 글캠 기숙사에서 살다보니까 왔다갔다하기 힘들거같아서 이중전공은 설캠으로 하게 되면 한 학기에 이중전공만 몰아서 들을 생각이었거든요..그리고 제가 찾아보니까 밑에서 첫번째랑 두번째 질문은 찾아봐서 답을 알았는데 글을 수정하려고 보니까 삭제밖에 안돼네요 ㅜ 정말 수고많으십니다.. 감사드려요ㅠ', '이중전공을 언제부터 듣는지는 상관이 없으며 졸업전까지만 학점을 채우시면 됩니다 그리고 이번에 신청하지 않으면 이후엔 이중전공 변경기간에만 신청할 수 있는데 잔여여석으로만 선발해서 경쟁이 치열하고 일단 배정되면 추후엔 변경이 불가능 하다는 패널티가 있습니다 토익점수 필요 여부는 경영학과 사무실에 문의하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 보험계리학 이중전공 변경 이중전공 이중전공 신청 기간 신청
# = 1학년 2학기면 신청기간에, 2학년이상이면 변경기간에', '저는 2학년 이상인데 이중전공을 한번도 신청한 적이 없는데도 변경기간에 하나요?', '1학년 2학기때에만 신청의 기회가 있구요, 신청안했어도 그 기회를 이미 상실하신거구요  그러면 이제 변경기간에 여석있는 학과만 신청할 수 있어요', '감사합니다!', '감사합니다^^ 추가적으로 이중전공 변경 기간에 배정받으면 추후엔 이중 변경이 안되니 참고바랍니다
# <  <EOS>
#
# > 이중전공 신청
# = http://builder.hufs.ac.kr/user/indexSub.action?codyMenuSeq=37080&siteId=hufs&menuType=T&uId=4&sortChar=AB&linkUrl=04_0202.html&mainFrame=right&dum=dum&boardId=17221&page=1&command=view&boardSeq=97538788', '감사합니다!', '감사합니다^^
# <  <EOS>
#
# > 전공 부전공 바꾸
# = 일전공을 이중 또는 부전으로 바꾸는 방법은 없습니다 전과를 해도 기존의 일전공을 이중, 부전으로 이수할 수 없으니 마찬가지입니다
# < 전공 수업의 경우 동일교과목으로 '확인했어요 학교소개 > 현황 > 전자규정집 > 2편 학칙의 학위수여규정을 확인바랍니다', '감사합니다 <EOS>
#
# > nan
# = 미배정자, 탈락자로 분류되어 2학년 때부터 이중전공 변경기간에 신청하셔야 됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 집안 경제 어렵 지방 내려가 휴학
# = 수업일수의 3/4 전까진 가능한걸로 알고있는데 되도록 빨리 학종지에 문의하시길 바랍니다', '현재는 질병 군입대 임신출산육아 관련휴학만가능합니다
# < 네 맞아요', '엠티 농활 체전 이런것두 포함인가요? ㅠㅠ', '농활은 아니고요 엠티랑 체전까지는 포함되요 쉽게 말하면 교수님 눈에 잘 띄면 됩니다 <EOS>
#
# > 이번 영어 영문 이중전공 학점 시험 보나
# = 보통 이중전공은 학교에서 평점, 이수학점대로 선발하지만 일부 학과에선 자체적인 절차로 선발하는 경우도 있습니다 학과마다 시험 등의 절차가 상이하기 때문에 해당사항은 학과사무실에 문의하셔서 선발에 필요한 절차를 알아보셔야 합니다', '감사합니다 즐거운 하루 보내세요!!
# <  <EOS>
#
# > 휴학 복학 16 학번 학년 상황 이중전공 17 학년 경우 가능
# = 아직 공고 안떠서 아무도 모를걸요 근데 아마 17만 될듯. 이번 이중전공 변경 공고 뜬거 보니 포함 안돼있었움', '현재 1학년 2학기 재학중이시면 금번에 이중전공 신청을 하셔야됩니다 엘디 엘티의 신청 가능 여부는 구체적인 공지가 다시 떠봐야 알 것 같습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 계절 학기 수요 정도 개설
# = 원칙적으론 30명이기는 하나 학과입학정원(전공), 전임교수여부, 필수과목여부 등에 따라 그때그때 달라집니다
# < 막학기가 규정된 건 불가능하죠 학종지 담당자와 조치를 받으시길 바랍니다 <EOS>
#
# > 학기 미네르바 교양 영어 계절 재수강 가능 겨울 계절 방학 교양 영어 미네르바 재수강 학기 교양 영어 미네르바 여름 계절 열리
# = 미네르바, 교양영어 모두 교양필수라 여름, 겨울계절 다 열리는 편입니다 1학기 수업은 여름에 개설되며 따라서 이 때 재수강하실 수 있습니다', '감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 학교 교내 음주 금지 학칙 금지 아니
# = 학생징계규정 상 교내 음주로 대학질서를 문란하게 한 경우엔 징계한다고 명시되어 있긴합니다 그러나 '대학질서를 문란하게 하면'이라는 전제가 있어 단순 교내 음주까지 무조건적으로 금지한다고 보긴 애매한 구석이 있습니다", '감사해요 ㅎㅎ
# < 네 그렇게 됩니다 <EOS>
#
# > 고생 교직 이수 포기 별다르 절차 필요
# = 교직 이수자로 해당 학과(또는 학종지 교직담당자)가 별도 관리하는걸로 알고 있습니다 해당 부서에 문의 후 취소와 관련된 절차를 안내받으시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 상반기 휴학 가을 학기 학기 내년 학기 학기 학점 이번 16 학점 수강 어디 년도 바뀌 이월
# = 학점 이월은 동일연도 내에서만 가능합니다(17년 1학기 -> 17년 2학기 이월 가능, 17년 2학기 -> 18년 1학기 이월 불가)', '아하 그렇군요 감사합니다!
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 이공 성적 장학금 대하 정보 어디
# = 전공만 잘봐도 주는 성적 장학금이 있나요? 기준을 알고 싶습니다 ㅠ 홈페이지 장학금 관련 된거 눌러봤는데 성적 장학금은 찾기가 힘들더라고요', '성적장학금은 학과 추천 명단을 통해 학생지원팀이 지급하는 구조입니다 따라서 선발 주체인 학과의 내부 기준에 따르며 그 기준은 학과마다 상이합니다 홈피에 안나왔다면 학과사무실에 문의하셔야 됩니다', '아하 그렇군요! 답변 정말 감사드립니다.
# < 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 부전공 관련 질문 남기 이중전공 경우 해당 전공의 필수 과목 부전공 경우 해당 전공 필수 과목 부전공 관련 수업 아무거 21 학점 학점 모르 채우
# = 부전공은 학사학위가 나오는 것이 아니기 때문에 전공필수, 졸업시험(논문) 등을 치룰 필요 없습니다 그냥 학점만 채우시면 됩니다', '정말 감사드립니다.  좋은주말 보내세요.
# < 네 그렇게 됩니다 <EOS>
#
# > 학년 이중전공 경영 신청 경영 이중전공 토익 점수 경영학과 자체 시험 통과 만약 부전공 시험 자격 조건 필요 학기 전공 이중전공 괜찮 학년 34 학년 수업
# = 1. 부전공도 학과에서 제한을 두는지는 잘 모르겠네요...이건 학과사무실에 문의바랍니다', '2. 이중이든 교양이든 학기별로 어떤 영역을 듣든 상관없습니다 졸업 전까지만 학점을 다 채우시면 됩니다', '3. 학과별로 수강 학년을 제한하는 곳도 있고 안하는 곳도 있습니다 이건 해당 전공을 개설하는 학과사무실에 문의하셔야 됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 작성 소수어 16 학번 71 선발 내년 학기 전공 국가 어학연수 제가 학기 전공 국가 학기 휴학 영어권 국가 영어 배우 프로그램 통하 모르 국제 교류 홈페이지 찾아보 이해 영어 장학금 힘들 경우 자비 유학 제도 어디 어떻 알아보 모르 부족 수고 감사
# = 학기, 학점 인정 상관없이 그냥 영어권에서 공부하고 싶으시면 칠쁠일 종료 후 일반휴학으로 갔다오시면 됩니다 이 경우엔 어디서 연수하든 본인 자유이지만, 학교에선 일체 지원이 없습니다 학점 인정의 경우에만 휴학 중 학점 인정 또는 해외계절학기 제도를 통해 6학점까지 인정이 가능합니다', '학기, 학점(최대 18학점)까지 다 받고 싶으시면 칠쁠일 기간 중 공지될 국교팀 영어권 교환학생 파견 공고를 통해 갔다오실 수도 있습니다 단 이 시기엔 칠쁠일 파견으로 한국에 없을 수도 있기 때문에 각종 서류제출 등에서 애로사항이 있을 수 있습니다(면접까지 있다면 더 어렵죠) 자비유학의 경우엔 절차가 조금 간소한 편이지만 교환, 칠쁠일과 달리 본교와 해외대학 양쪽 모두에 등록금을 내야하니 금전적인 부담이 큽니다 제 생각엔 국교팀에 영미권 교환 프로그램에 대해 문의한 후, 칠쁠일 가시기 전에 미리 관련 서류 등을 준비해 두시는게 좋을 것 같습니다', '1. 그냥 휴학 후 자유롭게 연수한 후 6학점 받기 2. 조금 복잡하지만 미리 관련서류나 일정등을 확인해서 칠쁠일 파견 기간 중 국교팀 영미권 교환에 지원하기 3. 돈이 많이 들지만, 절차가 조금 간단한 자비유학으로 가기', '1번은 휴학, 2번과 3번은 학교에 등록해야함
# < 칠플일은 선발은 칠쁠일, 교환 등 대부분의 차원에서 지원하는 장학금이라면 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 아너 프로그램 인턴십
# = 두개 총합 35학점 이하여야 합니다(국내외 최대교류학점) 만일 아너스 연수+인턴이면 최대 32학점이 되어 코트라 인턴은 불가능하지만, 아너스 인턴만 하여 최대 15학점만 얻는다면 추후 코트라 인턴 지원도 가능합니다', '정정: 아너스 연수(18)+인턴(15) 최대 33학점, 단 이는 학과마다 인정 가능 최대치가 상이함
# < 1. 휴학기간이 지나도 입대, 복무 및 조치를 받으시길 바랍니다 <EOS>
#
# > 감사드립니 제가 41 교환 42 코트라인턴 학기 남은 교양 외국어 학점 이론 가능
# = 네 가능합니다 코트라 인턴 8학기 파견은 그 다음학기에 졸업을 위한 필수학점이 1학점 이상 있다는걸 지원서에 기재하시면 됩니다(선발공지 참고바람)', '또한 4-1 교환, 4-2 인턴의 해외교류학점 총합이 35학점을 넘지 않으면 됩니다', '이전에 해외교류학점 취득 사실이 없음을 전제로 함
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 이중전공 신청 나중 변경 학점 복구 복구 학점 적요 학기 변동
# = 1학년 2학기 직후 성적을 반영하기 때문에 최초 신청 땐 추후 재수강을 해도 소용없습니다(겨울계절학기를 통한 재수강도 반영되지 않음) 단 이중전공 변경 신청 시엔 해당 시점의 성적을 반영하므로 이전에 이수한 재수강 성적이 반영됩니다', '앗 네 감사합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 겨울 계절 학점 교류 교환 학생 학점 교류 괴목 대체 학점 인정 홈페이지 어디 들어가
# = 특정과목 대체가 아니라 보통 전공, 이중, 교양, 자선 이런 식으로 영역별 학점을 인정받게 됩니다 학점 인정여부는 각 학과사무실 또는 교양대학에 문의하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 교양 영어 교환 영어 수업 대체
# = 교양필수, 전공필수같은 필수 과목들은 국내외대학 학점교류로는 대체할 수 없습니다
# < 네 그렇게 됩니다 <EOS>
#
# > nan
# = 네 파견학기가 8학기만 아니면 됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 경영학 사무실 어디 검색
# = 경영대학(사이버관503호, 02-2173-2334/2337)', '감사합니다^^
# < 네 그렇게 됩니다 <EOS>
#
# > 학기 다니 등록금 할인 이중전공 할인
# = 전공, 이중, 교양 상관없이 이수 학점대로 차감됩니다', '단 9학기부터 후기이중전공을 이수하는 경우, 본인의 소속학과가 아닌 이중전공학과의 단과대 등록금을 기준으로함', '이제 봤네요 답변 감사합니다~ 조교님 짱짱
# <  <EOS>
#
# > 수고 겨울 계절 학기 학교 수강 얘기 정보 대하 공지 알리 겨울 계절 학기 수강 가능 학교 대하 정보 어디 찾아보 감사
# = 학교홈 학사공지 2017학년도 겨울계절학기 국내대학 학점교류 확인', '대신 답해주셔서 감사합니다^^', '우와 감사합니다^^ 조교님도 감사해요!
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 편입 기존 학기 마치 졸업 부전공 신청 졸업 학점 학기 학기 신청 부분
# = 한국외대 재학년한은 최대 6년이며 편입생 분들의 경우 전적대학 학점으로 인정받은 2년도 포함되므로 실질적으론 4년입니다 즉 최대 4년까지 학교에 재학하셔도 무방한거니 따로 신경쓰실 필요 없습니다~', '감사합니다 !!!!!
# < 네 그렇게 됩니다 <EOS>
#
# > 생리공결제 대하 여쭈 제가 저번 금요일 수업 생리통 수업 빠지 생리공결제 저번주 시험 기간 빠지 수업 시험 수업 생리 결제 기간 주일 교수 서류 제출 못하 생리공결제 인정 교수 메일 말씀 드리
# = 원칙적으론 일주일 내 서류제출이지만 유고 인정 등 출석 모든 권한은 담당교수님 재량입니다 직접 찾아뵈 사정을 설명드리면 이미 사전에 메일도 보내드렸으니 이해해주실거라 봅니다', '아감사합니다ㅠㅠ 넵 !!
# < 그건 전공이냐 교양이냐의 문제가 아니라 교수님들 성향의 문제입니다 유고결석계의 수용 여부는 담당교수의 재량이기 때문에 설령 적법한 절차대로 발급된 유고걸석계라고 해도 담당교수님이 받아주시지 않습니다 <EOS>
#
# > 이중전공 때문 고민 문화콘텐츠 광고 브랜딩 전공 고민 강의 시간표 확인 서울 글로벌 캠퍼스 열리 전공 글로벌 캠퍼스 열리 강좌 서울 캠퍼스 열리 강좌 수업 부족 글로벌 캠퍼스 학생 제가 서울 캠퍼스 글로벌 캠퍼스 모두 열리 전공 이중전공 경우 캠퍼스 모두 수업
# = 문콘 글로벌에서만 수강가능 광고pr 서울 글로벌 모두가능', '이미 답변이 되었군요 감사합니다^^
# <  <EOS>
#
# > 과사 졸업 신청 성적 증명서 학점 모자라 겨울 계절 생각 끝나 상관없 물어보 500 아깝 다기 질문 드리 졸업 신청 필요 서류 겨울 계절 끝나 상관없
# = 졸업사정 절차 중 학과에서 하는 일은 졸업시험(논문심사) 및 결과 종합, 학생 개개인의 졸업 승인 여부를 학교에 보고하는 것입니다 여기서 학생의 성적증명서는 필요하지 않지만, 학과 자체적으로 졸업사정 자격(6학기 수료)를 확인하기 위해 제출을 요구했을 수도 있습니다 성적증명서 상의 성적은 졸업시험(논문심사)에 반영되지 않으므로 그대로 제출하셔도 됩니다 어차피 학과 졸업시험을 통과하게 되면, 학생이 학교에 제출해야하는 서류는 외국어공인점수 외엔 없기 때문에 나중에 다시 성적증명서를 제출할 일은 없습니다', '학과에서 성적증명서를 확인하여 학과에서 요구한 과목을 모두 수강했는지 확인하는 학과도 있습니다. 단순히 졸업사정 자격을 검토하는 것이 아니라 학과자체에서 실질적인 졸업사정을 하기도 합니다. 만약 글쓴분이 중국어대 학생이라면 그 성적증명서를 가지고 학과내규에 따라 영역별 학점이수가 안되어 있으면 졸업이 되지 안습니다.', '아 전필과목 이수 확인도 있겠군요...근데 그러면 6학기 수료자의 경우 7,8학기에 전필을 이수할 수도 있는데 이 경우엔 졸업 사정 대상에서 아예 제외되는 건가요? 학교 졸업사정규정상 일단 6학 수료자는 자격이 될텐데요...', '나중에 비슷한 질문에 답할 때 알아두어야 될 것 같은데요...만일 6학기 수료생(또는 7학기 재학생)의 경우 아직 두 개 학기가 남아 전필과목을 이수하지 않았을 수도 있는데 이 경우 학과졸업사정은 어떻게 처리되나요? 아예 사정 대상에서 제외되는건지 아님 일단 사정자격은 되니 조건부 승인을 해주는지 궁금합니다 학과에서 학교에 보고할때 가,부로 구분해 명단을 제출하는데 이 경우엔 어떻게 처리하는지도 알려주심 감사하겠습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 국제 스포츠 레저 학부 졸업 학사 나오
# = 국제스포츠레저 학사가 나옵니다(한국외대 학칙 2-2-1 학위수여규정)', '고맙습니다
# < 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 계절 학기 학기 학기 수강 과목 연결 학기 재수강 과목 여름 다음 계절 학기 재수강 겨울 다음 계절 사실
# = 해당학기의 수업을 바로 그 다음 계절에 재수강하지 못할 뿐입니다 만일 이번 2학기에 수강하는 수업이 있는데 겨울계절 신청할 쯤엔 이 수업의 성적이 아직 안나왔으니 재수강 자체를 신청할 수 없지요 그 외엔 동일, 대체과목이면 다 가능합니다', '보통 연강수업의 경우 1학기 수업은 여름계절에, 2학기 수업은 겨울계절에 개설되는게 원칙이니 참고하시길 바랍니다', '아 친절한 답변 감사합니다!! 제가 지금 전과를 생각하고 있는데 이번 겨울 계절로 1학기 때 성적 중 재수강할 수 있는 과목을 연계해서 재수강하고 휴학을 한 뒤 다시 복학해서 전과가 가능한지도 여쭤봐도 될까요...?', '2학년 진급예정자가 대상이므로 가능합니다 전과신청은 보통 1월 중에 진행되는데 해당시점의 성적을 기준으로 하기 때문에 휴학하기 전에 들었던 겨울계절 성적도 반영됩니다', '진짜 바쁘신 와중에도 친절하고 자세하게 설명해주셔서 감사합니다ㅎㅎ 남은 하루 잘 보내시고 굿밤 되세용~ :)
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 이중전공 아무것 신청 어떻 학년 학기 시작 신청 기회 아니 다음 년도
# = 미배정자로 분류되어 매학기 진행되는 이중전공 변경기간에만 신청하셔야 됩니다 단 이 때는 최초신청 이후 잔여여석으로만 선발해서 경쟁이 치열하니 1학년 2학기에 신청하는걸 권합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 계절 학기 횟수 제한
# = 횟수와 관련된 제한은 따로 없습니다~
# < 네 가능합니다 <EOS>
#
# > 관련 질문 이거 졸업 인증 다르 개념
# = 학교 졸업인증 flex와는 별도로 학과 졸업시험을 flex로 대체하는 곳도 있습니다 소속학과 또는 이중전공학과가 졸업시험을 flex로 대체하는지 확인바랍니다', '이중전공이 일본어학인데 졸업 인증으로 flex가 필요한 것으로 알고 있는데 그게 저것인가요??? 편람으로는 그냥 몇 점 이상으로만 되어있어서 따로 보고 내면 되는 걸로 알고 있었는데..', '해당공지를 어디서 했는지 알 수 없어 정확한 답변이 어려울 것 같습니다 학과 졸업시험 대체 flex는 학교 졸업인증과는 다른 개념이라 점수 커트라인은 학과 사무실에 문의하셔야 합니다', '네 늦은 시간 답변 감사합니다^^', '저거는 상공회의소 이외언어보는거에요 학사공지에 주요학사일정에 다나왔어요 봐야되는학과는
# < 네 그렇게 됩니다 <EOS>
#
# > 올리 학년 학기 재학 이번 학기 마치 겨울 방학 부전공 이중전공 올리 가능 가요 학기 수료 이중전공 바꾸 후기 이중
# = 이중전공 변경기간에 신청하실 수 있으며 2~4학년이 대상이니 학년과는 무관합니다 단 이전에 이중전공을 변경한 이력이 없어야 합니다 보통 4월이나 10월 경에 변경기간이 홈피에 공지됩니다', '변경신청은 했으나 변경안되었으면 괜찮은건가요??', '변경신청은 했으나 이중전공이 바뀌지 않았다면 괜찮습니다', '답변 감사합니다 조교님!!!!!!!
# < 1. 2학년이시니 이제부턴 변경신청으로만 신청가능합니다 단 이때는 종정시로는 안되고 설캠에서민 개설되던데 밀리게 됩니다 <EOS>
#
# > 이번 이중전공 경제 지역 경제 개발 협력 전공 바꾸 다르 아니 경제 경영학 교류 회계 원리 지역 경제 학점 인정 이외 지역 경제 학과 교류 과목 감사 생각
# = 혁신융합전공 과목이 금번에 신설되어 편람상에도 안내된 내용은 딱히 없는 것 같네요...해당 전공과 관련된 안내 공지는 있으니 아래의 링크에 첨부된 안내문에서 확인바랍니다 회계원리 인정이 가능하다면 학종지에서 이수구분 정정신청을 할 수 있습니다', 'http://builder.hufs.ac.kr/user/boardList.action?command=view2&siteId=haksa&boardId=17221&boardSeq=94428848
# < 네 그렇게 됩니다 <EOS>
#
# > 사범대 전과 관하 질문 사범대 사범대 전과 가능 동일 어문 전과 가능 캠간전과 동일 어문 올라가 확인 교과 언문 프교 프학부 감사
# = 1. 타 단과대 학생이 사범대로 전과하지 못할 뿐입니다 사범대생은 같은 사범대(잔여여석이 있을 때만) 또는 타 단과대 소속 학과로 전과할 수 있습니다', '2. 같은 중복학과만 아니면 동일어문도 가능하긴 합니다(예시: 글캠 이탈리아어통번역 -> 설캠 이탈리아어, 같은언어지만 통번역학이 아니기 때문에 가능) 단, 이전에 이수한 본전공은 모두 자선처리되며 이전 본전공은 추후 이중(부)전공으로 이수할 수 없습니다', '아 그리규 한가지질문더있슴니다.. 프교과에서 프학부에있는 세부전공으로 나중에 이중전공신청못하나요? 아니면 중교과에서 중외통 이중하는 식이나요!', '제가 설캠이 아니라 정확히 어떤 사정인지 잘 모르겠네요...쪽지 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 등록 휴학 가능 등록 휴학 이수 학기 반영 끝나 신청 등록 휴학 나중 재학 증명서 반영 긍금
# = 등록휴학을 군휴학으로 바로 전환하시면 됩니다(입영통지서 같은 증빙서류 필요) 그리고 등록휴학을 해도 복학하기 전에는 이전학기만 이수한 걸로 뜹니다
# < 네 그렇게 됩니다 <EOS>
#
# > 편입 졸업 요건 편입 이번 졸업 후기 이중전공 미네르바 수업 기타 등등 후기 이중전공 포함 후기 이중전공 바뀌 졸업 조건 맞추 빡세
# = 재학중이든 후기든 편입생이 이중전공을 할 시 졸업인증 공인외국어점수를 제출해야하며 교양을 비롯한 학점이수도 추가적으로 이루어져야 합니다 단 학점이수는 소속 단과대별로 다소 차이가 있기 때문에 이는 학종지 단과대 담당자에게 문의하시길 바랍니다', '편입생이 후기이중 한다고 교양이 추가되는 것 없습니다', '정정을 해야할 것 같은데 제가 알기론 편입생이 이중전공 시 15학번과 동일한 졸업학점과 외국어 인증을 해야하거든요 15학번과 동일한 졸업학점 충족 조건에서 교양은 아예 안들어가나요?', '해외라서 제가 직접 학종지에 문의하기가 어려워서요...알고 계신다면 대댓 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 수고 학기 나오 최소 이수 학점 12 미만 학기 인정
# = 그렇지 않습니다 최소수강학점 12학점은 수강신청 및 변경, 포강할때만 적용됩니다(4학년부턴 최소수강학점 없음, 한과목 이상만 들으면 됨)', '감사합니다!!
# < 네 가능합니다 <EOS>
#
# > 계절 학기 과목 최소 학점 학기 채우 학점 정도 학기 신청 최소 학점 학기 지나 학기 학점 괜찮 이야기 학기 학점 맞추 등록금 학점
# = 1. 한 과목만 들으셔도 됩니다', '2. 한 학기당 최소학점은 12학점인데 4학년부턴 해당되지 않습니다 따라서 9학점을 들으셔도 되며 추가학기에 7~9학점을 이수하면 등록금은 절반으로 차감됩니다(10학점부터 전액)', '우와....조교님 짱...넘 감사해요????????', '등록금 절반으로 차감될 경우 성적장학금이나 교내장학금 국가장학금도 중복적용될 수 있나요?', '9학기 부턴 국가장학금이 제한되며(한국장학재단 문의바람, 학자금 대출은 가능) 면학을 비롯한 일부 교내장학금도 제한됩니다 성적장학금은 지급을 결정하는 학과 재량이라 이는 학과사무실에 문의바랍니다', '감사합니다!!????
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 시험 기간 수고 17 학번 학생 71 우수파견 다녀오 학년 학기 평점 37 이상 학기 평균 평점 나오 학기 37 못하 평균 37
# = 1학년 2개학기 평균평점 3.7이므로 평균만 넘으면 됩니다', '감사합니다!
# < 칠플일은 전액 또는 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액
#
# > 재수강 가능 학점 얼마 어떻
# = 보통은 수강신청 장바구니 또는 신청할 때 오른쪽 상단의 재수강 가능학점에서 확인할 수 있습니다 그 외의 방법은 저도 잘 모르겠네요 ㅜㅜ
# < 지나가다가 댓글달아요 ㅋㅋ 그거 옛날에 됩니다 <EOS>
#
# > 학교 학교 학점 교류 가능 학교 가능
# = 매학기마다 변동이 있기 때문에 정확한 대학 리스트를 답변드리긴 어렵습니다 다만 매학기 학교 홈피 공지를 통해 국내교류대학 리스트가 지속적으로 올라오니 공지에서 국내대학 키워드로 검색해 참고하시길 바랍니다', '네~감사합니당
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 현재 학년 학기 재학 경영 부전공 경영 과목 경제학 과목 경제 이중전공 신청 학점 커트 라인 경영 이중전공 올리 이후 경제 이중전공 변경 이중전공 가능 질문 부전공 이중전공 변경 이중전공 변경 해당 하나 그렇 경제 이중전공 이번 학기 부전공 냅두 경영 부전공 경제 부전공 변경 가능 여기저기 나름 찾아보 원하 정보 질문 드리 질문 생각 모르겟 답변 부탁 드리 감사
# = 삭제된 댓글입니다.', '감사합니다ㅠㅠ!!!', '1. 네 같은 전공이라도 이중->부전->다시 이중은 1회 변경에 해당되므로 올리시면 안됩니다 2. 윗분 말씀대로 경제 이중 확정이면 일단 부전을 바꿔두는게 좋습니다 3. 네 부전은 변경에 제한이 없습니다 / 추가적으로 부전으로 경제를 했다가 재학 중 이중으로 바꾸는 방법과, 8학기까지 졸업요건을 갖춘 후 후기이중전공으로 올려 추가학기를 다니는 방법도 있습니다', '감사합니다!!
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 집안 사정 때문 등록 휴학 입학 장학금 학기 그거 등록금 알리 10 25 장학금 사정 자퇴 자퇴 제가 등록금 돌려받 장학금 들어오 어떻 등록금 아니 통장 들어오 자퇴
# = 보통 장학금 지급은 해당학기를 기준으로 합니다 즉 현재 재학중인 2학기까지 마친 후 자퇴를 하면 장학금을 그대로 수혜받지만, 2학기 중에 자퇴하면 해당학기 수혜자격을 상실하여 후순위자에게 장학금이 돌아갑니다 10월 중 지급이면 아마 통장으로 현찰 지급되는 후지급일텐데 자퇴 시기가 언제인지에 따라 달라질 수 있습니다', '학기 중 자퇴 후 환불받는 등록금과 학기를 다 마친 후 자퇴해서 수혜받는 장학금 중 어느 쪽이 더 나은지 따져봐야할 듯 합니다 등록금 환불은 수업일수의 3/4 이전까진 일정부분 환불받을 수 있으니 이는 학종지에 한번 문의하시길 바랍니다', '등록휴학했는데 일정부분 환불받나요?? 전 그대로 다 돌려받는줄 알았어요ㅠㅠ 수강신청도 안했구용..', '등록휴학과 자퇴는 다릅니다 등록휴학은 다음번에 복학한다는걸 전제로 하기 때문에 등록금을 환불해주지 않지만, 자퇴는 말 그대로 복학할 일이 없게되니 등록금을 일부 환불해줍니다', '네 감사합니다!', '일단 등록휴학한 상태에서는 장학금 수혜가 가능합니다', '방금 전에 등록휴학인걸 깜빡하고 답변드렸는데 등록휴학 상태에서 장학금 수혜 후 자퇴를 하면 아마 장학금을 차감한 등록금을 환불받게 될겁니다 결국 별차이는 없겠네요', '장학금을 차감했다는건.. 그러니까 원래 받을 등록금에 장학금을 포함해서 더 환불받는다는 건가요??', '아닙니다 예를 들어 등록금을 200을 냈는데 장학금으로 100을 후지급 받았다면, 추후 자퇴시 등록금 중 나머지 100만 환불받습니다', '아ㅠㅠ 그럼 결국 원래 돌려 받는 등록금이랑 똑같이 돌려받는 거군요ㅠㅠ 감사합니다', '등록휴학신청한 날짜가 개강이후이면 차감있음
# < 휴학 신청은 가능하지만 통상적으로 글로벌) 칠플일은 전액 또는 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액 반액
#
# > 제가 71 신청 발표 언제쯤 학과 선발 인원 경우 본교 등록금 장학 처리 외국 대학 등록금 납부
# = 칠쁠일 학과선발이면...저번달까지 선발 명단을 국제교류팀에 통보를 해야했으니 이미 확정이 되었을텐데요...일단 해당사항은 학과사무실에 문의바라며 등록금은 학생이 알고계신 내용이 맞습니다', '아! 저도 더 찾아보다가 선발되었음을 알았습니다. 감사합니다 ^^
# < 칠플일은 최대 18학점입니다 (전공인정은 추가학기 신청 및 신청 및 신청 시 그 때 참가 할 수도 있습니다 따라서 이건 문의하셔서 확실하게 확인바랍니다 <EOS>
#
# > 관련 답변 정정 안내 종지 민원 센터 답변 확인 제가 관련 하요 안내 드리 아래 정정 답변 게시물 해당 내요 쪽지 발송 상태 답변 대하 사과드리 정확 답변 위하 노력 감사 외국어 이수 상태 대체 기존 이수한 실요외국어 성적 조정 가능 이수 실요 외국어 학점 추가예시실요 영어 실요 영어 이수 상태 렉스 영어 701 이상 제출 시실요 영어 A0 실요 영어 처리 기존 이수한 실요 외국어 학점 조정은 제출 렉스 성적 동일 언어 가능 14 학번 해당 드림
# = 실용외국어 1,2 모두 이수한 경우에는 동일 언어 플렉스 성적을 제출해 1,2 모두 학점 조정 가능', '고생하십니다! 혹시  그러면 실용 중국어 1을 듣고 플렉스를 영어점수로 제출하면 어떻게 처리가 되는 건가요 ??', '실용영어 1,2가 따로 인정되며 실용중국어1은 변동 없습니다', '이 경우에 플렉스 성적 제출하는것 외에 다른 유료교육 들으면 인증되는것 있다고 들었는데 뭔가요? 그리고 방학 이후에 플렉스점수 제출하면 인정안되나요?
# < 넹', '답변 감사드려요ㅎㅎ <EOS>
#
# > 14 학번 제가 중국어 상태 경우 플렉스 나머지 중국어 대체 가능 대체 플렉스 중국어 인증 고생
# = 플렉스 중국어로 제출하시면 실용중국어2가 신규로 추가되며 기존의 실용중국어1은 학점 조정만 하실 수 있습니다 단 플렉스 영어로 제출하시면 실용영어1,2만 추가될 뿐 기존의 실용중국어1엔 변동 없습니다', '감사합니다!. 그러면 영어로 이수했을 시 실용 영어 1,2 를 플렉스 점수에 맞게 성적을 받고 실용 중국어는 자선 학점으로 들어가나요? 아니면 그냥 교양 학점으로 되는 건가요??', '교양학점입니다
# < 네 그렇게 됩니다 <EOS>
#
# > 부전공 학년 학기 기말고사 성적 들어가 성적 통하 선택 알리 감사
# = 금번 이중전공 배정은 1학년 2학기 성적까지 반영됩니다(겨울계절학기 제외)', '감사합니다 ! 시험도 끝났는데 푹 쉬세요 ~~
# < 네 그렇게 됩니다 <EOS>
#
# > 부전공 변경 기간
# = 이중(부)전공 배정이 완료되고나서 뜹니다 보통 1월이나 7월 경에 공지됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 졸업 필수 교양 관련 질문 드리 만약 과목 국가 사회 카테고리 수강 나중 과목 국가 사회 카테고리 수강 자선 학점 들어가 나중 학기 걸치 학점 계산 들어가 성적 학점 새내기 모르 질문 드리
# = 교양전체학점을 초과하지 않는 한 카테고리 상관없이 모두 교양으로 들어갑니다 또한 카테고리별 이수는 학번별로 최소 몇 개를 들으라는 뜻이므로 그 이상을 듣는 건 상관없으며 성적도 다 평점에 반영됩니다', '예를 들어 국가와 사회 카테고리를 1개 이상 이수해야 한다면 2개를 듣든 3개를 듣든 모두 교양학점 및 성적에 반영되며 국가와 사회 카테고리 이수는 완료가 된겁니다', '그렇군요! 답변해주셔서 감사합니다~ 항상 수고가 많으세요 화이팅!!!
# < 네 그렇게 됩니다 <EOS>
#
# > 학년 학기 마치 휴학 2018년 3월 학년 학기 복학 저희 학교 학년 학기 이중전공 신청 11 경우 어떻
# = 학생의 경우 2018년 1학기가 1학년 2학기이므로 해당학기에 신청하셔야 합니다 보통 5월 중에 이중전공 신청 공고가 뜹니다(1학기엔 5월 2학기엔 11월 이런 식입니다)
# < 1. 2학년이시니 이제부턴 변경신청으로만 신청가능합니다 단 이때는 종정시로는 안되고 설캠에서민 개설되던데 밀리게 됩니다 <EOS>
#
# > 이중전공 성적 학년 이중전공 신청 학년 정도 성적 복구 신청 가정 신청
# = 1학년때 신청하지 않으면 미배정자가 되어 2학년때부터 매학기 변경기간에 신청할 수 있습니다 07학번부터 이중(부)전공이 의무라 매번 신청할 수 있지만, 1학년 신청과는 달리 한번 배정받으면 그 이후부턴 변경이 불가하며, 1학년 우선 배정 후 잔여여석으로만 경쟁하므로 경쟁이 치열하다는 페널티가 있습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 휴학 유학 기존 휴학 기간 연장
# = 일반휴학 기준 최대 3년까지 가능하며 1년 단위로 신청할 수 있습니다 단, 1년 신청 후 한 학기만에 바로 복학하는 것도 가능합니다', '지금 휴학상태라면 복학할 시기가 다가올 무렵에 다시 휴학 신청을 하시면 됩니다~
# < 네 가능합니다 <EOS>
#
# > 글캠 국제 경영 이중전공 학생 제가 통계학 화요일 열리 이중전공 수업 다릉 겹치 금요일 경영 정보 이중전공 수업 인정
# = 경영정보 이중전공 수업은 원칙적으로 경영정보 전공 학점으로 들어갑니다..(안그러면 국경, 경정 수업을 따로 분리한 이유가 없지요) 과목명은 같지만, 현재 학생은 국제경영을 이중전공 중인데 수업은 경영정보를 듣는 셈이니 해당 학점은 자선으로 들어갈 가능성이큽니다..우선 국제경영 학과사무실에 문의하셔서 확인하시길 바랍니다', '이 통계학수업이 국제금융에서 열렸는데,  수업 대상을 경영정보학과, 국제경영, 국제금융전공생 등으로 여러개를 나누어 놓은 수업입니다.   수강편람에는 국제금융학과에서 열린 모든 수업이 국제경영에서 인정된다고 되어 있습니다', '경정이 아닌 국금에서 열린 수업이었군요 수업 전공인원제한이 제대로 안된 것 같은데 일단 수강은 하셨으니 인정가능할 것 같습니다', '시간표 캡처한 걸 못올리네요  국금에서 열린 통계학 중 경영정보 대상을 듣는거에요  아마 되겠죠??  학종지에 물어봐서 된다고 했는데, 아주머니가 약간 확실하게 말을 안해서 좀 불안했습니당..', '일단 수강편람 상에도 인정가능하다고 되어있는만큼 이제와서 안된다고 할 순 없을겁니다 나중에 자선으로뜨면 국경인정이 가능한 국금 수업이라는걸 근거로 이수구분정정 신청을 하셔도 됩니다', '오오 감사합니다 조교님!! 너무 큰 도움됬습니다 ㅜㅜ', '본래 같은 학과의 같은 수업을 국금, 경정, 국경 이렇게 분리한 것은 수강생에 따른 난이도나 진도 때문에 학과에서 임의대로 조정한 것입니다(첫댓의 전제였던 아예 다른과 수업이라면 전공이 달라지지만 같은과 수업이면 모두 해당학과 전공으로 인정되는건 변동없습니다) 따라서 이들 수업은 기본적으로 모두 국금이며 국금 수업은 국경으로 인정 가능하다고 편람에도 나와있으므로 크게 걱정안하셔도 될 듯 합니다~
# <  <EOS>
#
# > 교환 학생 나가 학기 면학 장학금 국장 나오 형편 아니
# = 교환학생은 보통 본교등록금을 납부하기 때문에 조건만 충족시키면 등록금 내에서 면학 등 교내장학금 수혜도 가능합니다~
# < 네 등록금 범위 내에서 국장 혜택을 받는데 국가장학금은 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 통해 신청 및 경우 장학금을 확인할 수 있는데 등록금 한도 내에서 강좌들이 있던데 본교에 등록금을 납부해야하기 때문에 이때는 등록금 범위 내에서 국장 혜택을 받지 못합니다 <EOS>
#
# > 휴학 여름 계절 가을 학기 복학 겨울 계절 졸업 커리 가능
# = 휴학 중 계절학기는 이수 후 바로 복학하시면 되며, 계절학기를 최종으로 졸업하는 것도 다 가능합니다~
# < 네 가능합니다 <EOS>
#
# > 외국어 인증 관련 질문 서양어 전공 경영 이중전공 14 학번 졸업 영어 인증 점수 토익 토스 점수 하나 제출 상관
# = 비영어 전공자의 졸업 영어점수 인증의 경우 flex, flex 스피킹, 토익, 토익스피킹, 오픽 중 하나만 내셔도 됩니다~', '친절한 답변 감사 드립니다!
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 이중전공 부전공 선택 이중전공 부전공 가능 이야기 가능 그거 제도 어떻 신청 가요 이중전공 삼중 전공 가능
# = 전공 이수 구분은 1전공 및 이중(부)전공 이렇게 두 개만 가능합니다 예를 들어 1전공 A, 이중전공 B를 이수하는 상태라면 타전공인 C를 들어도 다 자선으로 들어갑니다 따라서 삼중은 불가능하다고 할 수 있습니다', '나중에 이중전공을 B에서 C로 바꾼다 한들, 그 동안 이수한 B전공은 모두 자선으로 전환되기 때문에 이 경우에도 불가합니다
# <  <EOS>
#
# > nan
# = 네 듣기와 읽기만 보시면 됩니다~
# < 네 그렇게 됩니다 <EOS>
#
# > 질문 있습니다편람 보니 전공심화 부전공 자선 12 교양 26 자선 교양 38 괜찮
# = 네 상관없습니다 자선은 말 그대로 자유선택이라 각 영역별로 초과된 학점들은 다 자선으로 들어가거든요', '야심한 새벽에도...ㅠ 감사합니다', '해외라서 여긴 아직 안잡니다..ㅋㅋ
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 선택 학년 학년 학기 이중전공 선택 감사
# = 2학년 1학기부터 들을 수는 있으나 나중에 수강하셔도 되며, 졸업전까지만 필요한 학점을 채우면 됩니다 07학번부터 이중(부)전공은 필수라서 금번의 1학년 2학기 때 신청하여 배정받으셔야 됩니다', '감사합니다 !
# < 네 그렇게 됩니다 <EOS>
#
# > 국내 대학 학점 교류 동시 외대 수업
# = 본교를 포함한 여러 대학에서 하는 것도 가능합니다 단 수학학기 수는 1개로 보며 이수학점은 본교 포함 17학점으로 제한합니다', '항상 자세한 답변 감사합니다!!
# < 네 그렇게 됩니다 <EOS>
#
# > 교직이수 글캠생 계절 학기 교직 과목 방학 설캠 열리 교육학 과목 교직 학점 인정 교양
# = 교육학 관련 과목이라도 졸업전까지 이수해야할 과목이 따로 지정되어 있는 것으로 알고있습니다..제가 교직 관련은 잘 몰라서 인정 가능 여부는 학종지 교직담당자에게 문의하셔야 할 듯 합니다(학교홈피 우측 상단 검색창에 학사종합지원센터 검색 후 각 캠퍼스별 담당자 소개란에서 연락처 확인)
# < 네 가능합니다 <EOS>
#
# > 개인 특강 강사 모시 계시 분야 유명 학교 부르 요청 방법 프로그램
# = 첫번째 방법은 학과장 교수님께 건의를 드리는겁니다 각 학과별로 학과운영비가 지급되는데 가끔씩 학과에서 강사를 초청해 특강비를 지급하기도 합니다 또다른 방법은 취업관련강사일 경우, 진로취업센터에 문의하는겁니다 센터에선 꽤 적극적으로 강사 초빙을 하는데 한 번 건의해 볼 수 있을것 같습니다', '오오 네 감사합니다!
# < 네 가능합니다 <EOS>
#
# > 하십니까저 사범대 이중전공 사범대 언어 등등 이중전공 교사 자격증 나오 이중전공 교사 자격증 나오 어떻
# = 사범대를 제외한 일부 학과들도 별도의 교직이수 과정이 있고 소정의 기간에 신청을 받습니다 해당사항은 이중전공 학과사무실에 해당과정이 존재하는지 그리고 어떤 절차로 선발하는지 문의하셔야 합니다', '사범대 재학과 관계없이 비사범대학생들과 같이 교직 신청하는건가요?', '그리고 본전공과 이중전공의 교직선발을 따로하나요 같이하나요?', '사범대 여부를 떠나 이중전공 학과의 교직이수를 통해 교사자격증을 얻으려면 별도의 절차를 밟아야 하는걸로 알고 있습니다 각 학과마다 자격조건 및 과정이 상이하거든요 이건 우선 해당학과 사무실에 문의하셔야 됩니다
# <  <EOS>
#
# > 성적 평가 비율 안내 중간고사 기간 문의 예상 성적 평가 비율 안내 참고 바라 중간고사 성적 거두 바라 감사 성적 평가 비율 유형 11 이상 수업 30 35 이하 35 유형 10 이하 수업 교직 이공 실험 실습 교양 영어 진리 40 이하 60 인원 따르 비율 계산 소수점 올림 처리 비율 153 16 계산 재수강 위탁 외국인 학생 해당 평가 방식 제외 절대 평가 실시 11 수업 유형 수강 10 유형 수강 최고 평점 A0 제한 해당 비율 교수 재량 비율 조정 일반 수업 30 교수 재량 따르 10 20 제한 평가
# = 외국인학생: 외국국적자, 재외국민, 새터민
# < 네 가능합니다 단 전공학점 인정은 함께 총졸업학점을 모두 채웠습니다. 타과생 들을 수 없습니다 <EOS>
#
# > 재수강 다음 학기 아니 교양 영역 강의 재수강 인정
# = 재수강은 졸업전까지 해당과목을 다시 들으시면 되며, 폐지된 과목의 경우 재수강 연결로 들으시면 됩니다 교양 재수강은 교양 필수 과목 등을 제외하곤 영역 상관 없이 타 교양과목으로도 가능합니다(이 경우에도 재수강 연결을 해야함)', '영역도 상관없었군요ㅋㅋ 감사합니다!
# < 네 가능합니다 <EOS>
#
# > 시험 기간 질문 드리 만약 20 학점 도중 학점 짜리 수업 랭크 경우 18 학점 이수 20 학점 이수한 되나요 평점 반영 이수 학점
# = 이수학점은 F학점 수업을 제외한 18학점이 됩니다 그냥 미이수 과목이 된다고 생각하심되요', '감사합니다~ 공부 열심히 해야겠네요
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 칠쁠 신청 전공 학과 신청 아니 나라 학과 신청 하나 이중전공 학점 인정 이중전공 사무실 해외 강의 설명 인정 물어보 귀국 보고서 모르 칠쁠일 이것저것 해외 학교 연락 입학 수속 나라 사무실 학과 학생 도움 생각 질문 엄청 많아졌네
# = 보통은 소속학과에 신청하는데 전공과 관련없는 연수도 선발 가능한지는 소속학과에 문의해야합니다 이중전공학과에도 남는 티오를 땡겨오는 형식으로 신청하는 경우도 있긴한데 보통은 본전공생 학생들을 우선선발 합니다 학점 인정의 경우, 소속학과로 칠쁠일을 가도 학점인정은 이중전공학과에서 받을 수 있습니다 입학수속의 경우는 외국대학마다 차이가 너무 많아서 정식으로 국교팀을 거치는 경우도 있고 학생본인이 스스로 준비하는 경우도 있습니다 해당 국가의 연수 등의 도움 해당학과 사무실에 혹시 같은시기에 같은학교로 가는 학생들을 연결시켜 줄 수 있는지 문의할 수도 있습니다', '질문이 너무 많았는데 이렇게 자세히 답변해주셔서 감사합니다~!! 아, 우수성적으로 신청하면 티오 상관없이 갈 수 있는 거죠? 혹시 해외 대학에 조건이 있어서 학과선발은 됐는데 떨어지는 경우도 있나요?', '우수성적은 티오 상관없이 갈 수 있습니다 대신 이건 본교에서만 허용된 것이며 파견 해외대학 측의 별도 조건이 있어 이를 충족시키지 못하면 탈락할 수도 있습니다', '그렇군요.. 별도 조건이 있는지는 과사에 문의해봐야겠네요ㅎ 감사합니다~^^
# < 네 그렇게 됩니다 <EOS>
#
# > 교환 학생 관련 질문 드리 규정 학년 학기 신청 마감 학년 학기 교환 학생 신청 학년 학기 교환 학생
# = 현재 재학 신분인지 휴학 신분인지에 따라 다릅니다 예를 들어 3학년 1학기 직후 휴학을 하게되면 파견은 3학년 2학기로 갈 수 있으며 3학년 1학기 직후 재학중, 그러니까 3학년 2학기를 다니는 상태에서 신청하면 4학년 1학기로 파견을 갑니다', '단 칠쁠일이든 교환이든 8학기(4학년 2학기)에는 파견을 갈 수 없기 때문에 3학년 2학기로 파견을 가면 3-2, 4-1 로 1년을 갈 수 있지만 4학년 1학기로 가게되면 4-1 즉 한학기만 교환으로 갈 수 있습니다
# < 칠플일은 전액 장학금을 수혜받는데 입학장학생의 즉 전액 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 등록금 범위 내에서 국장 혜택을 받는데 국가장학금은 하면 장학금을 차감한 등록금을 환불받게 될겁니다 결국 별차이는 없겠네요', '장학금을 차감했다는건.. 그러니까 원래 돌려 받는 등록금이랑 등록금 납부 '학기 중 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 학점 복구 후 사람들도 많습니다.', '성능 좋은데 값싼 노트북은 무게를 포기하면 구할
#
# > 제가 학년 학기 학기 과목 수강 만약 이것 이것 이중전공 학점 반영
# = 1학년 2학기까지의 학점을 반영하므로 이중전공 심사 시 평점에 포함됩니다~
# <  <EOS>
#
# > 실외 렉스 대체 가능 학번 플렉스 시험 사정 렉스 공부 못하 질문 드리 학점 상관없 점수 실외 대체 가능 하한선
# = 701점 이상을 넘겨야 A0부터 평점을 받을 수 있습니다 그 아래의 플렉스 점수로는 대체할 수 없습니다 ㅜ
# < 네 그렇게 됩니다 <EOS>
#
# > 수고 71 선발 끝나 성적우수자라
# = 제가 알기론 저번 달 부로 다 끝났습니다 따라서 다음학기(보통 3월 경)에 지원하셔야 합니다
# < 네 가능합니다 <EOS>
#
# > 71 파견 학생 우수 적자 학년 학점 37 이상 작년 학년 학점 저거 공지 없어 언제 파견 학생 신청 우수 성적 전공 언어권 학과 파견 문의 드리 우수 성적 적요
# = 매학기 초에 선발공지가 뜨는데 그 때마다 국교팀 자료실에서 명단을 확인할 수 있습니다 우수성적자의 경우 소속학과에서 일괄 선발하며, 파견국 선택은 학생 본인 자유입니다(단 타 언어권 연수 시 학점 인정은 해당학과에 문의해야함)', '파견국 선택이 자유라는건 제가 동유럽 학과인데 중국이나 일본같은 곳으로도 선택할 수 있다는 건가요??', '동유럽학과라고 해서 파견을 무조건 동유럽으로 가야한다는 규정은 없습니다 다만 아무래도 파견인원이 제한되어 있다보니 소속 학과에서도 되도록 학과전공과 관련된 학생들을 선발할 뿐이죠 단 우수성적자는 학과와는 별도로 100프로 학교선발이며 따로 학과티오를 잡아먹지 않으니 학과에서도 제한할 이유가 없습니다', '대신 타언어권 연수를 통한 학점인정은 소속학과에서는 어려우니 타언어권 관련 학과에 문의하셔야 됩니다 또는 자선이나 교양으로 인정받는 경우도 있습니다', '그렇군요! 항상 감사합니다!!
# < 네 가능합니다 <EOS>
#
# > nan
# = 해당 전공이 아니더라도 학과 티오에 여유가 있을 시 학과선발로 갈 수 있으며 학과에서 선발이 어렵다면 국교팀 선발로 지원하셔야 됩니다 학점 인정의 경우, 영어권의 관련전공 수학 시 소속 1전공 또는 이중전공 학점으로 인정 가능한지 각 학과사무실로 문의바랍니다 단, 단순 영어 연수 시엔 아마 학과에서 전공학점으로 인정해주기 어려울테니 이 때는 소속학과에서 자선으로 인정받거나 혹은 교양대학에 문의해 교양으로 인정 가능한지 확인바랍니다', '예를 들어 전공이 컴퓨터공학인데 영어권에서 컴퓨터공학 관련 수업을 이수하신다면 학과측에서 전공으로 인정할 가능성은 있습니다 단 이는 학과 재량이며 만일 단순 영어 연수라면 전공과는 상관없어 아마 어려울 듯 합니다', '따라서 사전에 각 학과사무실 또는 교양대학에 문의해 학점인정이 가능한지 미리 확인바랍니다 자선은 소속학과에서도 인정해줄 수 있습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 71 성적우수자 등록금 장학금
# = 성적우수자면 등록금 전액 장학 처리됩니다~
# < 등록금 범위 내에서만 지급됩니다 일반 편입생들의 장학금 수혜 가능한 자에게 장학이라고 주셨네요 장학이라고 총3년(6학기)입니다 <EOS>
#
# > 고생 다르 아니 대체 학점 질문 드리 14 학번 학기 상태 12월 발표 성적 학점 인정 실외 학점 인정 학기 나뉘 들어가 그렇 지나 학기 대체 학점 영향 끼치
# = 쪽지 확인바랍니다', '쪽지 보냈습니다 확인 부탁드립니다 :)
# < 네 인정됩니다 <EOS>
#
# > 감사 다르 아니 성적 장학금 지급 대하 여쭈 지금 기한 지나 힘들 지급 세금 이야기 퍼센트
# = 장학금에서 세금을 뗀다고요? 글쎄요...전혀 들어본 적이 없는 말인데..어디서 들으셨나요?', '앗 에브리타임에서 본 이야기인데 후지급 기간이 지나 별 신경을 안 썼었는데 그럼 후지급은 장학 금액 전체를 주는 거였나요..?!', '장학금에서 세금을 뗀다는 말은 들어본 적이 없네요 그리고 후지급에 관한 일련의 문제들로 금번부터 설캠, 글캠 학생지원팀 모두 후지급을 하지 않기로 지침을 세웠다고 합니다', '세금을 떼는 줄로 알았는데 그렇군요.. 답변감사합니다!!
# < 네 그렇게 됩니다 <EOS>
#
# > 71 등록금 대하 여쭈 교환 학생 외대 등록금 71 제가 학교 등록금 저희 아버지 회사 등록금 지원 회사 71 외대 아니 학교 등록 영수증 나오 지원이 해요외대 나오 영수증 장학 처리 표시 해외 대학 영수증 첨부 인증서 아니 대학 부탁 영수증 외대 관련 내요 추가 등록금 지원 추석 고생 즐겁 추석 보내
# = 칠쁠일의 경우 외대 등록금은 보통 전액처리되며 해외대학에 등록금을 납부하셔야 됩니다 따라서 등록금 지원을 받고자 한다면 해외대학의 관련부서에서 등록금 납부 증빙서류를 받아야 됩니다(외대에선 따로 발급X) 해외대학 건도 지원해줄 수 있는지에 대한 여부는 회사의 지침을 확인하시길 바랍니다
# < 칠플일은 전액 장학금을 수혜받는데 입학장학생의 즉 전액 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 장학금을 받고있어 등록금 범위 내에서 등록금이 등록금이 0원이면 시행되더라도 졸업사정방닉은 각 단과대, 졸업논문이냐 시험이냐에 따라 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 응시시점이 결정되는 즉 휴학 중 인정받을 수 있는지에 대한 여부는 학과 선발은 전액이며 받으니 대신 2학년 수업이지만 내에서 무관합니다 <EOS>
#
# > 실요영어1 플렉스 대체 기존 실요 영어 학점 재수강 처리 가능
# = 플렉스 대체를 통한 실용영어 학점 조정은 동일언어라는 조건 하에서 실용영어 1,2 를 모두 이수해야 할 수 있습니다(14학번 이전) 따라서 플렉스 대체만 하시고 기존의 실용영어1은 따로 재수강을 하시거나 혹은 실용영어2까지 다 듣고 플렉스로 학점을 조정해야 합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 이중전공 광고 홍보 광고 홍보 미디어 커뮤니케이션 학부 세부 전공 방송 영상 언론 정보 강의 수강 전공 학점 인정받 일정 학점 신청 기간
# = 각 학과별로 수강인원 자격 제한 또는 전공인정 가능여부가 상이합니다 따라서 이는 해당학과 사무실에 문의하셔야 보다 정확한 답변을 얻을 수 있을 것이라 생각합니다
# <  <EOS>
#
# > 전공 경영 전공 광고 홍보 전공 소비자 행동 과목 과목 수강 만약 전공 소비자 행동 전공 교류 과목 전공 과목 변경 신청 기간
# = 보통 1,2전공 수업은 해당 전공으로 인정되니 2전공의 소비자행동 과목도 2전공으로 인정될 것으로 보입니다 전공교류과목의 전공 인정 여부는 해당학과 사무실에 문의바라며, 만일 1전공으로 변경이 가능하다면 사무실의 안내를 받아 이수구분 정정을 요청하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 추석 고생 다니 학생 학년 이수 인정 학점 이수 못하 유급 당하
# = 학년별로 이수학점이 정해져 있긴 하지만 사실상 형식적인 것이며 학년 진급 상의 제한 사항은 없습니다~', '정말 감사드립니다! 좋은 추석 보내세요 에타조교 화이팅!!!!
# < 네 그렇게 됩니다 <EOS>
#
# > 2017년 2월 입학 새내기 이중전공 신청 기간
# = 보통 11월 중 학교 공지를 통해 안내됩니다 각 학과에도 안내 공문이 발송되니 학과별 커뮤니티에서도 확인 가능하실겁니다~', '감사합니다!!
# <  <EOS>
#
# > 렉스 관련 질문 드리 12 학번 영어 12 이수 이번 렉스 봐서 700 이상 옛날 영어 학점 유지 에이 제로 바꾸 렉스 절차 옛날 학점 유지 학점 영어 자선 돌리 두서없 질문 추석 보내
# = 이미 이수 완료가 된 경우엔 동일언어라는 조건 하에서 학점 조정을 인정받을 수 있습니다 학종지 교양담당자에게 문의하시면 관련절차를 안내 받을 수 있습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 수고 이중전공 신청 학년 학점 복구 복구 학점 적요 신청 시기 시기 이중전공 시작 가능 가요 18 학번 신청 가능 가요 이중전공 신청 시기 신청 떨어지 예비 기다리
# = 1학년 2학기 때 최초신청을 하지 않고 2학년 때 학점복구 후 신청하시려는 계획인 것 같습니다 그러나 최초신청은 1학년 2학기에만 가능하며 2~4학년 땐 변경신청만 할 수 있는데 이 때는 잔여여석으로만 선발해서 학점을 복구한다고 해도 경쟁이 치열해 쉽지 않습니다 이중전공 탈락 시엔 미배정자, 탈락자로 분류되어 변경신청으로 배정받을 때까지 신청할 수 있습니다(단 변경신청으로 일단 배정받을 시엔 추후 변경 불가)', '1학년 2학기에 최초신청  :떨어지면 변경신청 때 바꿀 수 있는데 잔여여석으로만 선발함(총 2번 신청하는 것) 2~4학년 때 변경신청기간에 신청: 한번밖에 기회가 없음 이런 식 인건가요?', '네 맞습니다', '오해가 있을 것 같아 말씀드리자면, 배정될때까지 계속 신청할 수 있습니다 07학번부터 이중,부전공이 의무거든요', '아 네 계속 배정될 때까지 계속 신청할 수 있으나 잔여좌석으로 경쟁하기 때문에 경쟁이 치열하다는 말이군요ㅠ.ㅠ . 학점 복구 후의 학점이 적용되는건 맞죠?감사합니다:) 해외에 계셔서 휴일을 즐기시지 못하나요..?ㅠㅠ 그래도 좋은 추석되세요! 늘 수고하십니다~
# <  <EOS>
#
# > 고생 14 학번 실요 외국어 상태 플렉스 대체 가능 가능 성적 어떻 처리 가요
# = 14학번까지는 실용외국어(교양외국어)를 플렉스로 대체할 수 있습니다 701점 이상 A0 4학점, 801점 이상 A+ 4학점으로 대체됩니다(기존에 이수한 실용외국어 학점 및 평점은 유지됨)
# < ㅇ', '네 '오 감사해요ㅠㅠ', '혹시 이렇게 일치하면 동일과목입니다 <EOS>
#
# > 감사합니닷 만약 글로벌 캠퍼스 학생 서울 캠퍼스 이중전공 서울 캠퍼스 학생 글로벌 캠퍼스 이중전공 이중전공 교양 수업 아니 전공 학과 교양 수업
# = 교양수업은 1전공 학과의 캠퍼스에서만 수강 가능합니다...ㅜㅜ', 'ㅠㅠㅠㅠ네ㅠㅠ', '즐거운 추석 보내세여 조교님!', '계절학기 교양은 제가 설캠생 학생들이 글캠에서 수강하는 걸 본적은 있는데 저도 확실하게는 모르겠네요...이건 학종지 교양담당자에게 문의바랍니다..추석 잘 보내시고요 ^^;
# < 네 그렇게 됩니다 <EOS>
#
# > 행정 처리 과정 휴학 기간 휴학 포함 휴학 예외 전과 문제
# = 일반휴학과 군휴학은 별개입니다 만일 1학년 1학기 후 군복무를 한 다음, 1학년 2학기로 복학을 해도 학기 상 전과 신청 자격은 갖추게 됩니다~', '천사님 ㅠㅠ감사합니다
# < 네 그렇게 처리됩니다', '등록휴학이 안보이는데 이미 등록금을 내시면 됩니다 <EOS>
#
# > 감사 최고
# = 감사합니다^^ 이번 학기 좋은 결과 얻으시길 바래요~
# < 네 그렇게 됩니다 <EOS>
#
# > 수고 질문 계절 학기 교양 필수 과목 열리 하나 문화 예술 파트라 교양 선택 과목
# = 매학기 마다 메일로 수요조사를 하고 수요에 따라 수업이 그때 그때 개설됩니다 교양영역은 교양필수는 물론 문화와 예술 등 선택과목들도 꽤 열리는 편입니다', '아하 다행이다 감사합니다!
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 국내 대학 학점 교류 관련 질문 드리 기본 신청 조건 만족 별도 선발 과정 학기 군데 이상 학교 신청 학기 교류 대학 외대 수강 신청
# = 1. 선발 인원 초과시엔 학업성적 평점평균 순으로 선발합니다', '2. 가능합니다 단 동일학기 여러 대학에서 수학을 해도 수학학기 수는 1개로 봅니다', '3. 본교 취득학점 포함 17학점 이내에서 수강 가능합니다', '감사합니다!!
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 휴학 관련 내요 예전 찾아보 수강편람 휴학 관련 학교 규정 어디 휴학 제가 학년 학기 휴학 학년 학기 복학 반년 휴학 처리 반년 휴학 휴학 처리 소문 어떻
# = 1. 일반휴학은 총 3년입니다(2012년 2학기 이후 편입생은 2년)', '2. 휴학은 1년 단위로 가능하나, 반년만 휴학한 후 복학신청을 하면 그대로 반년 휴학이 됩니다', '항상 감사합니다!!?
# < 네 가능합니다 <EOS>
#
# > 학기 결석 에프 보통 경우 결석 일주일 수업 경우
# = 네', '한국외대 규정 상 학점인정은 수업일수의 3/4 이상이어야 됩니다 즉 수업일수의 1/4 이상 결석하면 학점인정불가, F가 되니 주2회 수업 × 16주 총 32회 중 8회 이상 빠지면 F입니다 단 출석 점수 및 평가는 전적으로 교수님 재량이라 원칙대로 하시는 분도 있고 그냥 4회 결석을 F로 매기시는 분도 있고 매우 다양합니다..', '1/4초과입니다 이상이 아니라', '1/4을 초과하여 결석한 것에 대하여 F가되는것입니다 16주 수업으로 5번이지 4번이 아닙니다', '아아...제가 착각했군요 4번까지는 괜찮습니다 5번부터 문제가 되니 1/4초과입니다 죄송합니다..ㅜㅜ', '학칙 제35조에 1/4을 초과하여 결석한자에대하여 수험자격을 상실한다고 되어있습니다', '네 감사합니다^^', '학칙상 1/4를 초과해서 결석하면 학점 인정이 불가하지만 사실 이는 형식적인 규정이며 보통 각 담당교수님들의 재량으로 결정됩니다 담당교수님께 한번 문의를 드리는 것이 좋을거라 봅니다
# < 네 그렇게 처리됩니다', '네 등록금 범위 내에서 사실 충족을 다 등록됩니다 <EOS>
#
# > 재수강 연결 기간 놓치 종지 처리
# = 재수강 연결기간이 꽤 지나서 어려울 듯 합니다 일단 학종지에 문의 바랍니다', '감사합니다!
# < 네 가능합니다 <EOS>
#
# > 학년 학점 교양 외국어 드랍 방법
# = 네 없습니다...ㅜㅜ', '그럼ㄷ지금가서죄송하다고싹싹빌고수업듣고시험봐도저는빼박에픈거죠?교수님재량이아닌거죠?', '포강 생각하고 여태까지 안가신거라면...일단 교수님께 말씀드려야 겠지만 원칙상 에프가 될 듯 합니다...
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 다음 학기 71 만약 이번 학기 교내 장학금 다음 학기
# = 칠쁠일은 등록금 전액 또는 반액 혜택을 받게 됩니다 전액으로 선발되면 등록금 범위 내 지급 원칙상 교내장학금 수혜는 불가능합니다 반액의 경우엔 나머지 반액의 범위 내에서 교내장학금 수혜가 가능합니다', '우수성적 선발은 전액이며 학과선발은 전액 또는 반액입니다', '성적장학금이면 그 다음학기로 넘어가요', '감사합니다!!', '칠쁠일 전액 장학 상태에서 성적장학금 수혜는 불가능하기 때문에 그 혜택은 후순위자에게 넘어갑니다....', '성적장학금은 다음학기 등록금에서 차감되는 것이 원칙인데 이미 칠쁠일 전액으로 차감되었다면, 더 이상 차감할 수 없으니 그 다음 순번자에게 돌아가기 때문입니다(칠쁠일 반액의 경우 나머지 반액을 차감받는 것으로 수혜가능)
# < 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 핑프 경제학 사이트 문의드려요 경제 이중전공 학점 100
# = 조교님은 아니지만 넹', '학과정원의 150%까지는 학교에서 학점으로 선발하지만 그 이상으로 넘어가 경쟁이 치열해지면 선발 절차가 학과로 넘어가 자체 선발을 하도록 합니다 인원 초과로 자체 선발을 한 적이 있는지 학과사무실에 문의해보세요~', '서울캠퍼스는 150%내에서도 학과기준에 의해 선발합니다
# < 대학의 경제학과의 경우 이중(부)전공을 신청할 수 없습니 <EOS>
#
# > 7쁠1 우서성적 파견 신청학생 신청자격에1학년의 2개학기 평균평점 이렇게 되어 있는데 이게 정말 1학년 성적을 의미하는 건지아니면 2-1 2-2 의 성적도 가능한건지 헷갈려요남학샹이라 군대 이후 3-1에 가게될 거 같은데1학년 성적이 별로라 걱정 돼서 질문드려요
# = 1학년 2학기 종료 후의 성적을 기준으로 합니다(이후 재수강 등을 통한 성적 향상은 적용 불가)
# < 네 그렇게 됩니다 <EOS>
#
# > 다르 아니 이중전공 학점 계산 때문 남기 정치 외교학 이중전공 신청 학기 학점 학기 학점 286 학기 학점 정도 이중전공 정외
# = 각 학과별, 지원시기별로 커트라인이 매우 상이하며 또한 학교 차원에서 공식적인 커트라인은 제공하지 않습니다...이중전공 게시판에서 정보 교류를 하면서 최대한 평점을 끌어오르시길 바랍니다 정외면 꽤 높을 것으로 생각하는데 2점대 학점이면 많이 어렵습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 새내기입니당 이중전공 관련 질문 지망 지망 지원 만약 떨어지 어떻
# = 그럴 경우 이중전공 미배정자, 탈락자로 분류되어 추후 변경기간에 다시 신청하셔야 됩니다', '그렇군요 감사합니다!
# < 1. 2학년이시니 이제부턴 변경신청으로만 수강편람 또는 1월이나 7월에 단일전공을 들으면 됩니다 이 때 듣다가 몇 학점 이상이라는 조건만 되는 경우도 있는데 그건 학과에서 자체적으로 정하도록 되어있습니다 따라서 이건 과사무실에 문의하셔서 확실하게 확인바랍니다(입학장학금 홈피 > 장학에서 장학금지급규정을 확인하실 수 있습니다 거기서 학교 홈피 > 전공교류과목 현황을 확인바랍니다', '네에! 감사합니다ㅠㅠ <EOS>
#
# > 질문 드리 다르 학과 선발 어떻 이루어지 경쟁 어떻 여쭈 입학 대하 자퇴 입학 기존 이수 학점 학점 평점 사라지 시작 입학 특별 조건 편람 입학 대하 정보 수고 감사
# = 1. 국교팀에서 학과선발 공문을 발송하면 학과에선 일정기간을 정해 선발절차를 진행합니다 보통 1학기때는 3~4월, 2학기때는 9~10월경 입니다 경쟁률은 시기, 학과마다 매우 상이해서 정확하게 답변드리기 어려습니다..이건 학과사무실에 문의해야됩니다', '2. 재입학을 해도 이전의 학점, 학기는 모두 유지됩니다 일반적인 재입학의 경우 소속 학과장님의 승인을 받으면 됩니다
# < 학년별로 배분됩니다 학년별 티오를 학생지원팀에서 통보하면 티오를 티오를 티오를 관련 선발은 대개 학과 차원에서 일로 말이 바쁘셔서 전화 해볼라고요', '전공몇개들으실생각이세요??ㅠㅠ', '전 이중이랑 전과 때 한 번 C나 경쟁하기 때문에 ㅜㅜ <EOS>
#
# > 졸업 논문 대하 질문 드리 군대 다녀오 이번 학기 마치 졸업 시험 대상 학년 수료 사람 대상 내년 학기 공고 시험 응시 학기 시험 학기 기다리
# = 3-2학기까지 완전히 수료한 상태여야됩니다 즉 4-1(7학기)부터 응시 가능합니다', '졸업시험은 매학기마다 실시됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 실요 외국어 대하 질문 드리 14 년도 학기 아랍어 학점 14 학년도 학기 실요 프랑스어 학점 15 학년도 학기 교양 프랑스어 학점 수강 실외 학점 들어가 프랑스어 학점 인정받 남은 학점 교양 인정 실요 아랍어 교양 학점 인정 기존 교양 프랑스어 플렉스 교양 학점 추가 가능 14 학번 플렉스 대체 성적 향상 가능 가요 교양 인정 종지 이야기 교양 분류
# = 1. 실용외국어는 교양필수과목입니다 즉 모두 교양학점으로 들어갑니다', '2. 이미 실용외국어 과정을 이수했기 때문에 대체가 아닌 학점만 인정됩니다 또한 플렉스 교양 4학점은 별도 인정으로서 기존에 이수한 실용(교양)외국어 학점이나 점수엔 영향 없습니다', '이미 프랑스어로 1,2를 완료하면 FLEX로 추가학점인정 안됩니다', '수정합니다 15학번 이후부터 2학점 인정 가능합니다(플렉스 대체X, 학점인정만 가능, 1회에 한함)', '3. 이미 교양학점이므로 별도 절차는 필요 없습니다
# < 네 그렇게 가능합니다 <EOS>
#
# > 답변 시간 안내 해외 연수 인하 시차 답변 시간 제한 존재 한국 시간 오전 현지 새벽 시간대 답변 드리 어렵 오후 저녁 무렵 질문 올리 최대한 빠르 시간 답변 드리 한국 중간고사 기간 모두 시험 바라 감사
# =
# < 네 그렇게 됩니다 <EOS>
#
# > 고생 여쭈 17 새내기 71 학년 학기 성적 37 재수강 계절 학기 성적 바꾸 가능 37 넘기
# = 평점 3.7이 넘어야 되며 1학년 종료 후 성적을 기준으로 하기 때문에 재수강 등으로 성적을 바꿔도 소용 없습니다', '그럼 3.7을 넘지 못하면 7+1기회가 아예없는건가요?', '우수성적으로는 안되며, 학과선발로 지원하셔야 됩니다', '계속 여쭤봐서 죄송한데...7+1관련 자료는 수강편람에 없던데 어떤 곳에서 참고해야하나요?', '국제교류팀 홈페이지 자료실을 참고바라며, 학과선발 방식 등의 문의는 학과사무실에 하셔야됩니다
# < 네 가능합니다 <EOS>
#
# > 부전공 이중전공 올리 어떻
# = 이중전공 변경기간에 동일하게 신청하셔야 됩니다 단 이전에 이중전공 변경 이력이 있으면 재학 중 1회라는 규정상 신청이 불가합니다
# <  <EOS>
#
# > 학우 분과 질문 시험 성적 학사 종합 센터 제출 정해진 기간 아니 제출 이번 성적 나오 제출
# = 학종지에 가면 졸업담당자가 계시는데 그분께 제출하면 됩니다 기간은 따로 없습니다~
# < 휴학 중 인정받을 수 있습니다 <EOS>
#
# > 학년 실요외국어2 이번 수강 대체 가능 점수 나오 점수 제출 이번 학기 수강 과목 학점 예전 과목 점수 대체 대체 수강 과목 강하 수강 과목 학점 변경 이번 학기 수강 재수강 처리 질문
# = flex로 대체해도 기존에 이수한 학점은 그대로 유지됩니다 그리고 대체를 한다면 지금 듣는 실용외국어2는 굳이 들을 필요가 없게됩니다', 'flex로 교양 4학점 A 또는 A+로 새로 추가되는 개념입니다 기존에 이수한 실용외국어엔 영향이 없고 그대로 유지됩니다', '앗 감사합니다. 예전점수는 못지우는군요 ㅠㅠ', '죄송한데 그럼 실용영어1,2를 다 들은사람도 flex를 치고 교양 4학점을 추가할수 있다는 말인가요?', '동일언어는 점수대체만 되는거같은데요. 영어외 다른언어 플렉스는 추가될걸요?
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 제가 상경 전공 언어 전공 71 지원 전공 지원 하나 아니 전공 지원
# = 상경 학점을 취득하시는 건가요 아님 언어 학점을 취득하시는 건가요?', '그건 아직 안정했는데 그럼 학점 취득하고 싶은 걸로 지원하면 되나요??', '보통은 그렇게 하는 편이긴 한데, 이중전공생의 선발 여부는 각 학과마다 차이가 있습니다 따라서 언어로 하고 싶으시면 이중전공생도 선발 가능한지 이중전공학과에 문의하시길 바랍니다
# < 칠플일은 사정에 따라 달라질 수 있습니다 이건 학과 측에 문의해보셔야 합니다 학기별 수요나 기타 사정에 따라 인원 조건을 달라질 수 있습니다 이건 학과 사무실에 문의바랍니다 <EOS>
#
# > 휴학 신청 오늘 결재 불리 취소 취소
# = 곧 수업일수의 1/4가 될텐데 그 전에 빨리 학종지에 문의하시길 바랍니다 1/4가 넘어가면 학점, 학기 인정이 어려워질수도 있기 때문입니다', '넵 고맙습니다!
# < 네 맞아요', '엠티 농활 체전 이런것두 포함인가요? ㅠㅠ', '농활은 아니고요 엠티랑 체전까지는 포함되요 쉽게 말하면 교수님 눈에 잘 띄면 됩니다 <EOS>
#
# > 사범대 저번 교환 학생 교직 과목 인정받 과목 수강편람 가지 나오 과목 알리
# = 교직과목 인정 여부는 전적으로 해당 학과 혹은 학종지 교직담당파트에서 관리합니다 교직은 제가 잘 몰라서 매번 관련부서에 문의해달라고 하는 편인데 교환학생 교직 인정과 관련해 제가 답변을 한 기억이 없네요...학과 사무실 또는 학종지 교직담당파트에 문의바랍니다 어떤과목이냐 그리고 소속 학과에 따라 다소 차이가 있기 때문입니다..
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 전과 학년 이전 신입 세미나 수강 전과 신입 세미나
# = 신입생세미나는 교양필수과목으로 학과 수업과는 상관없습니다 즉 전과를 해도 유효한거니 또 들을 필요는 없습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 지금 휴학 신청 등록금 돌려주
# = 지금 휴학신청하면 등록휴학으로 전환되서 자퇴 등의 사유가 아닌 한 되돌려받긴 어렵습니다', '수업일수 1/4 전에 휴학 신청하길 바랍니다 이후엔 어려워질 수 있습니다
# < 네 그렇게 처리됩니다', '확인 감사드립니다! <EOS>
#
# > 이중전공 전공 상대 캠퍼스 교양 수업 학생 글캠 이중전공 교양 글캠 열리 수강
# = 글캠에서 이중전공을 이수하셔도 교양은 서울캠에서 들으셔야 됩니다..
# < 네 그렇게 됩니다 <EOS>
#
# > 학년 제가 학년 이중전공 타과 전공 필수 수업 이번 학기 지금 자선 인정 내년 이중전공 선택 이중전공 학점 전환 인정 아니 자선 남나요
# = 이중전공 신청으로 해당전공을 이중으로 배정받으면 이수한 학점들은 자동으로 이중전공 학점으로 전환됩니다 단 배정 후에도 계속 자선으로 남는 경우도 있는데 이 때는 학종지에 이수구분 정정 신청을 하시면 됩니다', '감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 질문 가지 학년 학기 끝나 겨울 학기 학점 채우 졸업 가능 가요 수료 취업 다음 논문 토익 나중 졸업 제출 건지
# = 1. 네 가능합니다', '2. 네 가능합니다 단 재학한 학기수+수료 학기 수가 12학기를 넘으면 제적처리되니 그 전에 제출하셔야 됩니다', '그럼 2년 이내에 내야하는 거군요', '네 8학기로 수료하시면 4개 학기 즉 2년 내로 제출하셔야 됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 재수강 제한 학기 동안 재수강
# = 재학중 최대 18학점입니다(단 계절학기를 통한 재수강은 차감되지 않음)
# < 네 가능합니다 <EOS>
#
# > 제가 수강편람 교양 과목 카테고리 하나 카테고리 하나 교양 최소 이수 학점 졸업 교양 학점 자선 학점 채우
# = 학번별로 기준이 상이합니다 쪽지로 알려주시면 답변 드리겠습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 71 파견 제도 전공 학교 파견 최대 18 학점 인정받 이중전공 과목 인정 18 학점 인정 과목 무엇 어떻
# = 이중전공 과목의 학점인정은 전적으로 이중전공 학과(장)에게 권한이 있습니다 아마 학과 차원의 내부규정이 있을텐데 최대인정가능학점, 인정가능과목 및 수업 내용 모두 포함되어 있습니다 따라서 해당학과 홈피 또는 학과사무실에 문의하셔야 됩니다', '감사합니다!
# < ㅇ', '네 '오 감사해요ㅠㅠ', '혹시 저렴한 한데 언제 학점 인정이 될 수도 있어요', '으앙 이렇게 친절할수가...!!!ㅠㅠㅠ동북아도 알아봐야겟다 관심이 아예업는것도아니어서요!!으ㅠㅠㅠ진짜감사함니다!!', '궁금한거 있으면 힘들 것 같기도 하고해서 감사합니다^^', 14학번이 혼란스러워ㅠㅜ그리고 관심잇다고 하기도 무섭고해서..퓨', '동북아는 한중일+미국 러시아 북한의 정치경제사회문화 등에 대해 대해 배우고 배우고 배우고 보시면 됩니다 <EOS>
#
# > 이수한 교양 자기 전공 관련 과목 전공 학점 이수 신청 가능 사실
# = 전공과 관련 있는 교양이라도 전공 학과에서 인정하지 않는다면 그냥 교양 수업입니다 학점 인정 여부는 전공 학과 사무실에 문의 바랍니다', '감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 학년 17 학번 학기 17 학점 여름 방학 학점 인정 교육 봉사 농활 갔다오 학기 17 학점 학점 짜리 교양 하나 드롭 방학 갔다오 교육 봉사 선택 이중전공 조건 34 학점 포함 이번 학기 15 학점
# = 농활과 마찬가지로 해당 봉사 활동도 학점인정이 된다면 이중전공 심사 시 2학점 다 포함됩니다~', '답변 감사드려요ㅎㅎ
# < 농활과 마찬가지로 봉사 활동도 학점인정이 된다면 가능합니다 그 때 배정받지 수도 심사 시 이수해야할 체크를 한 수강 시 그 때 상관 없습니다 <EOS>
#
# > 답변 제한 안내 해외 연수로 인해 금일 출국 이로 인해 일요일 월요일 답변 제한 질문 올리 최대한 빠르 시일 답변 감사
# =
# <  <EOS>
#
# > 수두 걸리 학교 경우 유고 인정 방법 가능
# = 전염성이 있다는 걸 확인하는 의료기관 명의의 증명서를 받으셔서, 소속학과 사무실 또는 학종지 소속 단과대 담당자에게 유고 발급 여부를 문의하시길 바랍니다 각 학과와 소속 단과대 모두 자체적인 유고 규정이 있기 때문입니다
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 종강 이중전공 경영 변경 경영 계절
# = 이중 변경 전에라도 경영과목을 자선으로 들을 수 있습니다 이중 변경 후 해당 자선학점들은 다 이중전공 학점으로 전환 가능합니다 단 해당학과에서 전공, 이중전공생용으로 수강 제한을 두는 경우도 있기 때문에 강의 비고란이나 강의계획서를 확인하시고 수강하시길 바랍니다', '계절 비고란에 글로벌 경영정보, 국제경영, 국제금융, GBT 전공/이중/부 인정 이렇게 쓰여있는데 이중경영으로 변경 전에도 들을 수 있는 건가요??', '변경 전에도 자선으로 수강 가능하고 변경 후엔 자동으로 이중(부)전공으로 전환됩니다 단 가끔씩 변경 후에도 자선으로 남는 경우가 있는데 이 때는 학종지에 방문하시어 이수구분 정정신청을 하시면 됩니다', '아 네!감사합니다조교님!!
# < 네 그렇게 됩니다 <EOS>
#
# > 영어 번역 학부 부전공 영어 전공 가능
# = 특정학과의 내부적인 커리큘럼 및 학과 학칙 등은 제가 확인하기가 어렵습니다...해당 학과 홈피 또는 학과사무실에 문의바랍니다 ㅜㅜ
# < 네 합니 <EOS>
#
# > 전과 이중전공 불가 그렇
# = 전출학과의 이중(부)전공이 불가능하다는 뜻입니다 예를 들어 경영학과 학생이 화학과로 전과했다면 추후 경영학을 이중(부)전공으로 이수할 수 없다는 뜻입니다 즉 전에 있던 학과 외의 전공을 이중으로 들으셔야 됩니다(전출학과 학점들은 자선 전환됨)', '감사합니다..!!ㅠㅠㅠ진짜!
# <  <EOS>
#
# > 지금 수업 하나 포강 고민 교수 스타일 아래 나오 수업 의문 생기 질문 수업 점수 학점 포기 망하 경우 재수강 회생 방법
# = 타 대학과 달리 우리학교는 학점포기제가 따로 존재하지 않습니다 재수강을 안하신다면 해당 학점은 졸업할 때까지 안고 가셔야 됩니다..
# < 네 그렇게 됩니다 <EOS>
#
# > 국장 면학 장학금 등록금 등록 못하 오늘 추가 등록 기간 놓치 학교 휴학 다니
# = 수업일수 1/4전까진 가능할겁니다 월요일 되자마자 학종지 찾아가셔서 조치를 받으시길 바랍니다', '넘 다행이네요 감사합니다ㅠㅠ
# < 네 수직으로 확정됩니다 등록금 범위 내에서 등록금이 책정됩니다 <EOS>
#
# > 제가 면학 장학금 신청 신청서 구부 어디 표시 모르 국장 이번 신청 소득분위 나오 일반 가계 곤란 표시
# = 저도 2분위로 많이 신청했는데 따로 일반가계곤란으로 표기하지는 않았습니다 해당 조건에 필요한 증빙서류가 따로 있는지 학생지원팀에 문의바랍니다(근데 분위만 맞으면 다 지급되는걸로 알고 있거든요 저도 매번 해당없음으로 표기했지만 잘 받아왔습니다)
# < 칠플일은 전액 장학금을 수혜받는데 입학장학생의 즉 입학장학생의 즉 전액 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 장학금을 받고있어 등록금 범위 내에서 등록금이 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 장학금을 받고있어 등록금 범위 내에서 등록금이 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 장학금을 받고있어 등록금 범위 내에서 등록금이 혜택을 받는데 국가장학금은 등록금 범위 내에서만 지급됩니다 즉 전액 장학금을 받고있어 등록금 범위 내에서 지급됩니다 즉 장학금을 받고있어 등록금 범위 내에서 등록금이 혜택을 받게 '성적장학금이면
#
# > 편입 졸업 요건 남은 학점 전공 25 학점 자선 학점 32 학점 만약 상황 제가 부전공 이중전공 21 전공 42 학점 추가 수강하요 부전공 3221 이중전공 3242 채우 졸업 요건 갖추
# = 편입생의 경우 부전공은 21학점 이상을 취득해야 하며 이중전공은 15학번 신입생과 동일한 졸업학점을 이수해야합니다(단과대 별로 차이 있음) 또한 외국어 인증도 함께 치뤄야됩니다 이중이든 부전공이든 편입생은 일단 학종지에 방문 상담할 것을 편람에서 권장하고 있기 때문에 11월 쯤 신청기간 전에 학종지에 문의하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 교환 학생 모집 기간 국제 교류 홈페이지 파견 기간 나오 칠쁠원 교환 포함
# = 보통 국교팀의 영미권 연수 선발은 칠쁠일, 교환 등 대부분의 프로그램을 활용해 선발합니다 국가 또는 학생 희망에 따라 신청하는 편인데 본인이 가고자 하는 나라에 칠쁠일, 교환 둘 다 가능한지 국교팀에 문의하시는게 좋을 듯 합니다(학과선발전형이 아니기 때문에 학과와는 관련 없습니다)
# < 네 수직으로 처리됩니다', '등록휴학이 안보이는데 그냥 등록휴학으로 처리되므로 '보통 장학금을 선지급 등록금 범위 내에서 등록금이 책정됩니다 <EOS>
#
# > 어문 부전공 경우 해당 학과 졸업 요건 정하 응시 홈페이지 확인 이중전공 전공 합격 기준 부전공 안보요서 중국 외교 통상
# = 부전공생은 학사학위를 얻는 과정이 아니기 때문에 전필, 졸업시험, 영어점수 등 학과가 정한 졸업요건을 지킬 필요가 없습니다 학점만 채우시면 되요~
# < 네 그렇게 됩니다 <EOS>
#
# > 제가 재수강 신청 마음 바꾸 초수강 연결 재수강 미완료 방문 문자
# = 아마 연결하지 못한 경우라 판단하고 문자를 돌린 거 같네요 학종지에 연락해 사정을 설명하시길 바랍니다', '앗 감사합니다!!!
# < 네 가능합니다 <EOS>
#
# > 수업 드랍할려 수업 나가야 하나 드랍 시간표 빠지
# = 드랍하면 수강신청에서 아예 사라집니다 그리고 어차피 드랍할 수업인데 굳이 나갈 필요는 없죠 ㅋ (교수님께 미리 말씀드리는게 좋긴 해요 종이 출석부로 체크하시는 분은 드랍한 줄 모르시고 계속 학생을 찾으실수도 있거든요)', '헤헤 감사합니다....!
# < 넹', '감사합니다! 비고에 1전공 가능한가요?? > 캠퍼스 높은 사람들이 전에 과마다 다른듯?', '답변해주셔서 감사합니다~ :) <EOS>
#
# > 제가 학년 학기 휴학 햇다 2017 학기 학년 학기 이중전공 신청 안햇
# = 1학년 2학기에 신청을 안하셨다면 2~4학년 미배정자 또는 탈락자로 분류되어 이중전공 변경기간에 신청하셔야 됩니다 5월이나 11월 중에 변경기간이 공지되는데 매번 홈피에 뜨는 공지 잘 확인하시고 신청하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 브릭스 전공 브릭스 과목 경제 강의 수강
# = 상경트랙의 경우 경영, 경제 관련 수업을 이수하셔야 되는데 학번마다 조건이 상이해서 정확한 답변이 어렵네요 ㅜㅜ 편람에 Brics를 검색하셔서 본인의 트랙, 학번에 맞는 조건을 찾아보시길 바랍니다', '중국어전공 16학번인데...봐도 잘모르겠어서요
# < 네 그렇게 됩니다 <EOS>
#
# > 과목 제한 학기 학점 이상 이상 수강 금지
# = 각 영역별로 필수, 선택사항으로 몇 학점 이상 들어야 된다는 조건은 있지만 특정 영역에서 몇 학점 이내로 들어야된다는 조건은 없습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 건강 이유 등록 휴학 학년 학년 학기 복학 게목표 이중전공
# = 금번에 휴학하고 내년 1학기에 복학하면 학년은 1학년 2학기인 채로 등록됩니다(소위 엇복학) 따라서 복학한 학기엔 여전히 1학년 2학기 신분이기에 이중전공은 해당 학기에 신청할 수 있습니다', '이중전공 최초신청 자체가 1학년 2학기, 당해연도 편입생이 대상이기에 언제 복학을 하든, 그 신분만 유지되면 신청 자격을 얻을 수 있습니다', '감사해요????
# < 네 그렇게 됩니다 <EOS>
#
# > 우수 파견 대하 이해 부분 질문 드리 우수 파견 학생 입학 장학금 학생 제외 대상 이유 우수 파견 입학 장락 부류 때문 우수 파견 학생 티오 상관 파견 부분 일반 파견 학생 다르 입학 장학금 이유 혜택 박탈 당하 이해 입학 장학 속하 이유 모르
# = 입학장락>입학장학*', '감사합니다 조교님??', '음 그건 학교에서 정한거라 제가 어떻게 답을 드리기 어렵네요 다만 입학장학금 자체가 전액 또는 반액을 받으며 학교를 다니는 건데 거기다 또 장학 혜택을 주어 파견을 보낸다면 다른 학생들과의 형평성에서 문제가 될 수 있지요..거기다 입학장학금 수혜를 받는다면, 굳이 칠쁠일 장학 혜택을 받을 필요 없이 자비 유학을 가도 학교 등록 상에 입학 장학금 혜택을 얻을 수 있기에 제한된 예산을 운용하는 학교에서도 굳이 입학장학생들을 칠쁠일 우수파견으로 뽑을 이유가 없지요...칠쁠일 선발이 되도 우수입학생들은 어차피 장학 혜택을 받고 이는 중복 수혜가 안되니 차라리 타 학생에게 주는게 낫죠...제 추측이지만 이러한 이유 때문이지 않을까 싶습니다...
# < 칠플일은 최대 혜택을 받을 수 있습니다 <EOS>
#
# > 졸업 시험 안내 학교 홈피 통하 졸업 시험 안내 공지 지금 학과 졸업 시험 공문 도착 학과 자체 시험 일정 공지 아래 공통 사항 숙지 바라 감사 어디 신청 전공 졸업 시험 전공 학과 사무실 이중전공 졸업 시험 이중전공 학과 사무실 문의 신청 전공 폴란드어 이중전공 경제학 학생 이중전공 졸업 시험 응시 경제학 사무실 신청 폴란드어 사무실 X2 졸업 시험 어떻 자체 졸업 시험 치르 플렉스 대체 학과 차이 해당 학과 사무실 문의 응시 자격 졸업 시험 논문 규정 학년 수료 대상 학년 학기 학기 학생 응시 졸업 시험 대상자 개별 통보 경우 이번 학기 응시 희망 학과 사무실 문의 신청 바라 기타 조건 학과 졸업 시험 별도 졸업 조건 경우 영어 점수 현장 답사 논문 작성 대하 해당 학과 사무실 사전 문의 처리 졸업 시험 치르 바라 감사
# = 추가: 부전공은 해당사항 없습니다', '그 졸업시험이랑 졸업논문은 둘다 해야 하는 건가요 아님 둘 중 하나 선택해야하는건가요? 혹시 과마다 다른건가용?
# < 네 그렇게 됩니다 <EOS>
#
# > 국제 학생 발급 아무 어디 수고 감사
# = 학교 재학생이면 누구나 발급받을 수 있고 종합정보시스템 후생복지관리 -> 국제학생증 텝에서 신청할 수 있습니다 일반형이냐 또는 체크카드형이냐에 따라 발급처가 다른데 이건 종합정보시스템에서 확인할 수 있습니다 추가적으로 가끔씩 학교 공지를 통해 무료 발급 이벤트가 열리는데 이를 활용해 발급받으셔도 좋습니다~
# < 네 그렇게 됩니다 <EOS>
#
# > 이번 겨울 계절 학기 수강 신청 계절 학기 과목 편성 이루
# = 작년에는 11월초에 겨울계절학기 안내 공지가 떴고 11월 말쯤 수강신청을 했습니다 아마 이번에도 비슷할텐데 공지 전후로 해서 홈피 강의시간표나 수강신청 핫링크에서 과목 편성을 확인할 수 있을겁니다~', '아아ㅏㅏㅏ 넵 감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 등록금 자신 장학 내역 어떻 확인 등록금 확인
# = 종합정보시스템 -> 등록장학정보 -> 장학내역에서 수혜받은 모든 장학금을 확인할 수 있습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 등록금 추가 납부 기간 어떻 지금 문자 날아오 모르 추가 등록금 납부 기간 등록금 어떻
# = 등록금 고지서를 들고 은행에 납부하셔도 되고 가상 계좌로 이체하셔도 됩니다 납부 후 하루 이틀 뒤에 종합정보시스템 등록장학정보->교육비 납입 현황에서 확인가능합니다', '감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 경영학과 이중전공 신청 토익 점수 언제 준비 학과 시험 언제 알리
# = 학과별로 일정, 전형이 상이하니 경영학과 사무실에 문의바랍니다 ㅜ
# <  <EOS>
#
# > 학년 학기 16 학점 신청해놨는데드랍 기간 학점 드랍 추가 학기 다니 상황 학기 최소 학점 12 학점 가능
# = 4학년은 12학점 미만으로 드랍 가능하지만 한 과목 이상 수강하셔야 됩니다~', '답변 감사합니다~^^
# < 취업계 최종학기 말까지 내면됩니다 <EOS>
#
# > 교양 영어 대체 14 학번 이전 대체 교양 영어 수강 상태 성적 제출 교양 영어 수강 인정
# = 15학번 이후 교양외국어 이수는 flex로 대체할 수 없으나(학점인정만 가능), 14학번 이전 실용외국어 이수는 flex로 대체할 수 있습니다 즉 14학번 이전만 flex로 대체 가능합니다
# < ㅇ', '네 재수강은 동일과목으로 이수하는게 원칙이나, 폐지과목이나 선택교양 등에 한해서 타 타 타 타 타 타 타 교양으로 이수한 것으로 보입니다 이 때 교양은 캠간 이수가 가능합니다 <EOS>
#
# > 17 학번 이중전공 신청 기간 언제
# = 작년 기준 11월 즈음이었습니다 이번에도 비슷할 듯 하네요~', '감사합니다!
# < 네 그렇게 됩니다 <EOS>
#
# > 핵심 교양 졸업 필수 요건 영역 과목 이상 학점 채우 영역 채우
# = 특정 영역에서 몇개를 들으시든 4개 영역 1과목 이상 8학점 요건만 충족시키시면 됩니다~
# < 네 그렇게 됩니다 <EOS>
#
# > nan
# = 네 등록금 납부 맞습니다~', '감사합니다~
# < 네 그렇게 됩니다 <EOS>
#
# > 졸업 신청 취소 가능
# = 졸업시험(논문) 일정을 각 과사무실마다 공지 했을텐데 그 전에 신청했다가 취소하는건 가능합니다 단 시험(논문)을 치르고 심사를 거쳐 학교까지 결과가 제출되었다면 그 때는ㅈ되돌리기 어렵습니다 우선 학과사무실에 문의바랍니다', '감사합니당 :)
# < 그건 저도 잘 모르겠네요 학종지 소속 단과대(졸업) 담당자와 학종지 소속 단과대(졸업) 담당자와 인터넷 발급을 인정하지 않는 것으로 보입니다 학종지 문의 글로벌) 031-330-4027', '감사합니다ㅠㅠㅠ <EOS>
#
# > 다음 학기 복학 예정 군인 다음 학기 복학 제가 무턱대 학년 마치 이중전공 신청 면접 당일 버리 경우 이중전공 신청 언제
# = 일단 종합정보시스템 전공/교직관리-> 이수중인 전공에서 이중전공이 어떻게 되었는지 확인해보시길 바랍니다 면접을 안가셨으면 미배정 또는 타전공 배정이 되어있을텐데 매학기마다 변경신청공고가 뜨니(5월 또는 11월 중) 그 때 신청하시길 바랍니다', '감사합니다 ~~
# < 4-1학기로도 들을 수 있습니다 <EOS>
#
# > 이중전공 신청 위하 정규 학기 학점 학점 부족 상태 그러 겨울 계절 포함 아니 걱정
# = 이중전공 우선배정 34학점보다 모자르다는 것을 뜻하시는것 같습니다 그러나 아쉽게도 금번 이중전공 신청에서 겨울계절학기는 포함되지 않습니다 ㅜ', '34학점이 우선배정인건가요? 경쟁률 낮은과는 그러면 34이하여도 된다는 말씀인가요...?', '34학점을 우선적으로 배정하고 그 다음 34학점 미만인 학생들이 배정됩니다 34 미만이라도 배정될 수 있지만 경쟁에서 밀리는건 어쩔수 없지요 ㅜ 경쟁이 낮은과라면 기대해볼만 하지만 보장되지는 않는다는 뜻입니다 잘 되시길 바래요 ㅋㅋ ㅜ
# <  <EOS>
#
# > 이중전공 부전공 변경 신청 학년 한정 17 학년 사람 가능
# = 부전공으로의 변경은 학년 제한 없이 소정의 기간 내에 신청할 수 있습니다 보통 이중전공 확정 직후인 1월 또는 7월 즈음에 뜹니다', '감사합니당 ㅠㅠ
# < ㅇ', '부전공 변경기간 때 신청하시면 됩니다 <EOS>
#
# > 부전공 전공 필수 과목
# = 부전공은 학위를 취득하는 것이 아니라서 전필, 졸업시험(논문)은 할 필요 없습니다 그냥 학점만 채우시면 됩니다~', '감사합니다 !!!!!!
# < 네 그렇게 됩니다 <EOS>
#
# > 계절 학기 교양 열리 전공 열리 만약 전공 열리 계절 학기 기간 하루 시간 수업 학점 시간
# = 계절학기에 전공수업을 여는 건 학과 마다 차이가 있으니 과사무실에 문의바랍니다 계절학기 3학점은 매일 3시간 씩 약 3주 가량 들으신다고 생각하시면 됩니다', '아하 감사합니다 조교님 !', '3학점 4시간이면 3학점이어도 하루에 4시간 들어야 해요', '글쿠나 감사합니다', '아 3학점 4시간 수업이군요 그럼 계절학기때도 매주 4시간 수업입니다', '네 ㅠ감사합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 강의 이중전공 정하 나오 나중 이중전공 과목 정하 이중전공 학점 인정
# = 학생의 이중전공 신청, 변동여부에 따라 기존에 이수한 학점도 자동으로 변동됩니다 실제로 미리 들으면서 신청하는경우도 있습니다 가끔씩 이중전공 확정됐는데 그 때까지 자선으로 남는 경우도 있긴 하나, 그런 경우엔 학종지에 이수구분 정정 요청하시면 처리됩니다~', '감사합니다~??
# <  <EOS>
#
# > 재수강 연결 과목 어떻 처리 연결 상황 재수강 아니
# = 따로 연결 안하셨으면 아마 초수강 처리되었을 겁니다 종합정보시스템->수업수강관리->수강신청확인에서 해당 과목 재수강 여부가 어떻게 되어있는지 확인해보세요
# < 네 그렇게 됩니다 <EOS>
#
# > 댓글 제가 전공 전공 일본어 아니 일어 현재 이중전공 관련 수업 이렇 경우 어디 신청
# = 학과선발, 우수성적으로 가는 거라면 소속학과에 신청해야합니다 단 학과선발의 경우 학과 티오를 소모하는만큼 전공언어가 아닌 타 언어권으로의 연수는 학과에서 제한할 수 있으니, 소속학과에 타 언어권 연수도 선발할 수 있는지 문의바랍니다(단 우수성적은 학과티오를 소모하는게 아니니 학과에서도 따로 제한을 두는 편은 아닙니다)', '학점인정도 전공, 이중 둘 중 어느것과도 관련이 없어 해당학과 전공으로 인정받긴 어려울 것 같습니다 자선으로 인정받거나 또는 교양대학에 문의하여 교양학점 인정가능여부를 문의바랍니다 칠쁠일 선발과 학점인정은 별개이거든요', '자선은 소속학과에서도 인정가능합니다', '감사합니다!', '일어로 이중전공수업을 듣는것도 학점인정 가능한지의 여부는 해당학과에 문의하시길 바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 어떻 학점 교류 아니 신청
# = ocu의 학점교류여부 및 학점인정범위는 각 대학마다 차이가 있으며 이는 학과와는 별개로 진행됩니다 학종지 국내외학점교류 담당자에게 우선 문의바랍니다', '네!!감사합니다 ㅎㅎ
# < 네 그렇게 됩니다 <EOS>
#
# > 자선 학점 교양 학점 인정 자선 자선
# = 자선은 자선일 뿐입니다', '전공, 이중(부)전공, 교양을 제외한 수업들은 모두 자선처리됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 전공 어문 계열 자기 전공 언어 칠쁠 배우 고르
# = ㅇ근데 학점인정도 어렵고 일단 선발 안해줌', '우수성적인 경우 조건만 갖추면 학과에 신청 시 본인이 원하는 언어권으로 갈 수 있습니다 학과 티오를 소모하는게 아니니 학과 입장에서도 선발에 부담이 없거든요 그러나 학과 선발 칠쁠일은 학과의 일정 티오 내에서만 선발하는 만큼 되도록 전공언어권으로 가는 학생들을 선발할 수 밖에 없습니다 또한 전공, 이중전공과 전혀 상관없는 언어라면 교양이나 자선 정도밖에는 학점 인정을 받을 수 없어 졸업학점을 채우는데도 무리가 따를겁니다', '우수성적도 학과에 신청하는 건가요? 그럼 해외에서 이중전공 관련 수업을 들으려면 이중전공 학과에 신청해야 하나요?', '아, 자세히 알려주셔서 감사합니다!!!^^', '영미권 칠쁠일 연수는 국교팀에 문의바랍니다
# < 네 그렇게 됩니다 <EOS>
#
# > 저희 학교 포스터 부착 학교 도장 공문 필요 도장 공문 제출 경우 어디
# = 자세하게는 모르지만 각 단과대, 부서별로 게시판이 있을텐데 그 게시판을 관리하는 쪽에 문의해보시는게 좋을듯 합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 71 학기 교환 학기 가능
# = 2개 학기 35학점 내에서 가능은 합니다 단 학과선발의 경우 타 학생에 대한 기회제공을 위해 두 번 연속으로 선발하는걸 제한하는 경우도 있으니 이는 학과사무실에 문의바랍니다', '학과 선발 7+1, 학교선발(영중일) 교환은 괜찮은거죠?', '그 반대의 경우도요?', '2개 학기 35학점(계절학기 포함) 선에서 가능합니다~
# < 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 71 학기 연장 학기 동안 다녀오 가능
# = 삭제된 댓글입니다.', '아 그렇군요. 감사합니다', '앗 조교님 저는 작년에 칠쁠일 직후 다시 칠쁠일로 다녀왔습니다...', '칠쁠일은 과거 국내외교류 프로그램을 이수한 경우엔 지원이 불가능하게 되어있는데...이번에 기준을 1년으로 연장했다는 얘기를 듣긴 했지만 그게 바로 적용된건가요?', '두개의 다른 학교를 칠쁠원으로 두번 지원해서 간 경우와 하나의 학교에서 칠쁠원기준으로 1년 다녀온 경우 두 케이스 모두 있습니다!', '아 그렇군요 기회 균등을 위해서 학과마다 한 번 갔다오면 다음엔 제한하는 경우가 있는데 안 그런 경우도 있었군요...정정하겠습니다 감사합니다^^', '2개 학기 35학점 내에서 칠쁠일 두번, 총 1년 다녀오는 것도 가능합니다 단 학과마다 차이는 있으니 두번 선발이 가능한지 학과 사무실에 문의바랍니다', '잘못 설명드린 부분은 삭제하겠습니다 제보 감사합니다
# < 3,6,9,12월에 국제교류프로그램 학점인정 공지가 뜹니다 공지에서 안내하는 절차대로 하시면 됩니다 <EOS>
#
# > 이중전공 부전공 내리 대하 수강편람 신청 기간
# = 보통 방학 중 이중전공 확정공고가 난 직후에 공지됩니다 저번에는 1월 중에 떴습니다', '부전공 1월중순 7월중순 후기이중 4월중순 이중변경 5월초 11월초
# <  <EOS>
#
# > 학년 학기 17 학기 17 학점 농활 다녀오 이중전공 때문 걱정
# = 이중전공은 34학점 이상을 우선선발하는데 이 경우엔 농활 포함해서 36학점이니 조건은 갖추어졌습니다 평점만 잘 받아두세요~', '감사합니당????', '재수강은 포함 안된거죠? 그럼 36맞습니다', '재수강해야할 과목없어서 재수강은안했습니다!!', '그런데 조교님 종정시에 농활학점이 안뜨는데 이건 혹시 나중에 뜨는건가여ㅠㅠ??', '나중에 다 뜰겁니다 저도 농활 갔다오고 나서 한참 있다가 떴어요 이중전공은 2학기 성적 나오고 나서 심사가 진행되는데 그때쯤엔 이미 떠있을겁니다', '아아 ㅎㅎ 감사합니다!!!!!!
# <  <EOS>
#
# > 이중전공 부전공 질문 이중전공 듯하 부전공 돌리 지금 이중전공 학점 자선 처리 자선 자선 졸업
# ...
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 이중전공 어떻 학기 40 높요야
# = 경제추천드립니다', '이유를 여쭤봐도 될까요??
# <  <EOS>
#
# > 일통 이중전공
# = 언어쪽은 프리패스', '미달이라 컷 없어요', '감사합니다...
# <  <EOS>
#
# > 이중전공
# = 넵
# <  <EOS>
#
# > 이중전공 경제
# = 삭제된 댓글입니다.', '이유는??
# <  <EOS>
#
# > 학점 평균 30 정도 어디 이중전공 어문
# = 삭제된 댓글입니다.', '그러쿤요... 열심히 하겠습니다...??', '경영까지가능
# <  <EOS>
#
# > 미커이 학점 필요
# = 4에 수렴 but 일단 젤 중요한건 티오가 나야함', '이중인데티오가무슨티오ㅋㅋㅋ이중은150받게돼있어', '그니까 이중이건 전과건 티오상관없이 150% 5% 받게 되있는데', '전과는 4.0이상', '전과할때 학점만 봄?', '면접도있음 근데미커는존빡세
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 학점 학기 커버 장난 아니 시험 통과 수학 요트 이중전공 후기 남기 학점
# = 저 3.7 국통하지마세요 과목안열려요. 경제하세요', '아 진짜요...?', '네 경제할걸 후회중임. 국통이 경제보다 컷높아서 그냥 높은거햇는데 핵별로', '제가 외교관 쪽 하고 싶은데 그거랑 관련된 거 많은게 국통 쪽인 거 같아서 하려고 했거든요ㅜㅜㅜ 그렇게 안좋은가요..?', '제 주관으론 별로에요. 국통에서 배우는 과목들이 님 하고싶은것과 관련잇으면 하셔야죠.', '전 4초반이었어요. 전 제가 배우고 싶던 분야라 지금 만족하면서 수업 듣고있습니당 국통에서 열리는 수업목록도 보시고 글쓴이분께서 잘 결정하시면 ㄱ될것같네여
# < 네 그렇게 됩니다 <EOS>
#
# > 학기 성적 28 이중전공 어문 똑같 어문 경영 이중전공
# = 2학기 잘 하면 되죠 ㅎㅎ', '경영 토익점수랑 학점3.0기본깔고 학과시험만 통과하면 이중됩니다. 티오많이남아요
# <  <EOS>
#
# > 경제학 이중전공 학기 36 힘들
# = 보통3.7-3.8생각하면 된다더라고요', '가능
# <  <EOS>
#
# > 이중전공 어떻 무리
# = 삭제된 댓글입니다.', '통대생이라 통대 두개하면 너무 힘들 것 같아서..안그래도 아랍어 엄청 어려워서 포기하는 과생들 많다 들었어ㅠㅠ', '난 마통 추천... 취업잘돼
# <  <EOS>
#
# > 이중전공 한번 변경 가능
# = 한번밖에못함', '놉', '이중에서 부전으로 바꾼건데도...불가능 하죠? ㅠ', '후기이중만 가능
# <  <EOS>
#
# > 이중전공 정도
# =
# <  <EOS>
#
# > 전공 상경 이중전공 으르 융소 좋을까요 고민
# = 융소', '융소 2222
# <  <EOS>
#
# > 경영 이중전공 평균 학점 정도 이번 36 정도 나오
# = 삭제된 댓글입니다.', '왜?', '..? 3.0만 넘으면 된다던디
# <  <EOS>
#
# > 학년 학기 이중전공 변경 어떻
# = 나 3학년 1학기때 변경했는데 후회 안해! 내가 하고 싶은 거 적성에 맞는 거 하니까 오히려 마음이 편하더라구..
# <  <EOS>
#
# > 경영 이중전공 학기 성적 학기 32 정도 나오 이중전공 이중전공 신청 학기 가능 학기 학년 재수강 학년 학기 이중전공 도전
# = 걍시험통과하면다붙어요~', '정말요...? 그럼 희망이 조금이라도 있네요ㅜㅜㅜ', '엄청많이떨어져요', '시험을요?', '삭제된 댓글입니다.', '헐... 그렇게 어려워요?', '안어려움', '다들 떨어진대거ㅜ', '안되도 나중에 변경하면 됨. 만약 이번에 안되도 자유선택으로 경영전공과목들 들어놓고 나중에 변경신청기간에 신청 ㄱㄱ
# <  <EOS>
#
# > 국제 전공 이중전공 학점
# =
# <  <EOS>
#
# > 국제 금융 이중전공 학점
# = 3후반
# <  <EOS>
#
# > 이중전공 필요 요건 어디 찾아보
# = 어디 과는 인증 점수도 필요하다 그러는데 그런 걸 정확히 어디서 볼 수 있죠ㅜㅜㅜ?', '이중전공 하고싶으신 해당학과 홈페이지 공지사항에 있는 경우도 있고 그렇지 않은 경우에는 따로 필요한 요건이 없다고 보시면됩니다!
# <  <EOS>
#
# > 전과 이중전공 전과 이중전공 신청
# = 이중을 먼저신청함', '이중먼저 그 다음 전과
# <  <EOS>
#
# > 사학 이중전공 어떻
# = 전공이랑 같이 살려서 취업할 수 있느냐가 문제..', '하 지 마 세 요 제 발
# <  <EOS>
#
# > 이중전공 35 신청 가능 수강편람 나오
# = 각 과마다 기준 다름.', '각과 홈페이지 가서 공지사항 뒤지면 잇더라구', '없어 그런거
# <  <EOS>
#
# > 이중전공 학년 평점 35 신청 못햇 그러 나중 이중전공 신청 학년 학기 성적 학기 성적 포함 평균 35 이중전공 기간 기준 학기 평균 35
# = 후자야. 근데 2-1학기 신청은 어차피 1학년 성적반영이라...', '1학년 전체 평점 ㅠㅠ', '헉ㄱ그러면이중전공 변경기간때 신청해야겟다..이전글보고 대혼란와서 적어봄 요정님사랑함
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 신청 이번 학기 학점 짜리 나오 버리 다르 에이쁠비쁠 사이 때문 학점 타격 학기 올리 의지 이중전공 신청 부전공 이중전공 나중 바꾸 방법 하나 모르
# = 전공 에프에요? 아님 교양?', '과목이 티오가 나는거면 부전공으로 하다가 복구해서 이중 변경하면 됌 ㅇㅇ', '미네르바라서ㅠㅠ그것만 복구하면 될것같긴한데 이중전공은 생각도 못하고 있었던 제가 바보같아요ㄸㄹㄹ ㅇ후기이중전공은 전공이랑 부전공 학점을 다 이수한 후에 신청할 수 있던데 그 외에 성적관련한 제한은 없는거겠죠?!', '후기까지 안가도 될텐데 대부분', 'ㄱ그러면 이중전공 신청하고 될때까지기다리면 되는건가요??', '넹', '으아진짜감사합니다!!
# <  <EOS>
#
# > 베트남어 이중전공 관련 정보 알리
# = 베어 토익필여할텐데', 'ㄹ컼,.', '토익 800이던데', '낮네', '나한텐 넘나 높은 거', '이중전공못하면 부전공내리지말구 다음학기에 다시 이중신청하면되겟지', '??
# <  <EOS>
#
# > 마인 이중전공 학점 정도
# = 학점 컷 없음
# <  <EOS>
#
# > 이중전공 지망 지망 아니 하나 신청
# = 1지망 2지망 입니다^^', '감사합니다
# <  <EOS>
#
# > 행정 이중전공 경영 부전공
# =
# <  <EOS>
#
# > 경영 이중전공 필요 학점 건강
# = 경영 학과게시판 찾아봐', '스스로 찾아보는 노력이 젤 필요함
# <  <EOS>
#
# > 이중전공 학년 학점 학기
# = 얼마나 죽쑤셨는지 모르겠지만 총합 4점대거나 4점에 수렴하지 않으면 어렵습니다', '네', '지금 삼점초반정도 나올 것 같은데 2학기때 학점 4점넘기고 이중시험 잘보면 가능성있을까요?', '힘들듯. 2학기 4.5맞아도 총점 3.8정도일텐데', '3.6이어도 충분해요ㅋㅋㅋ', '뭐지 누가 맞는거죠', '이중하고가 더 힘들죠', '2.대도붙음시험에서많이갈림
# < 네 그렇게 됩니다 <EOS>
#
# > 전공 베트남어 이중전공 스페인어 어때사과대 관심 상경 괜찮 언어 하나
# = 별로야', '취업 할거면 무조건 상경', '언어 두개 비추..', '절대 ㄴㄴ
# <  <EOS>
#
# > 이중전공 중국 외교 학점
# = 하면 될걸
# <  <EOS>
#
# > 인문대 이중전공 추천
# = 어디에 관심있는지 알아야 추천을...', '난 내전공 좋으니까 동북아 ㅎㅅㅎ', 'ㅠ사실내가뭐에 관심있는지 모르겠고 혼란스러워ㅠㅜ그리고 관심잇다고 덥석 하기도 무섭고해서..퓨', '동북아는 한중일+미국 러시아 북한의 정치경제사회문화 등에 대해 배우고 외교 뿐만 아니라 무역 문화 등도 배워서 재밌음 그리고 무엇보다 수강인원이 적어서 B유형 강의가 많아서 부담없이 공부를 할 수도 있어요', '으앙 이렇게 친절할수가...!!!ㅠㅠㅠ동북아도 알아봐야겟다 관심이 아예업는것도아니어서요!!으ㅠㅠㅠ진짜감사함니다!!', '궁금한거 있으면 더 물어봐요!
# <  <EOS>
#
# > 전과 이중전공 쪽지
# = 과 상관없나요?', '이중 변경도 되나용
# <  <EOS>
#
# > 익씨 이중전공 바꾸 고민 어떻
# =
# <  <EOS>
#
# > 이중전공 미디어 커뮤니케이션 학점 이중전공 가능
# = 세부전공마다 다르고 얼마인지 정확히 아는 사람 없음 다만 4에 수렴해야한다고 들음', '미컴 이중전공생인데 3.8이상이면 붙을거에요', '캠간이면 3.8도 힘들어요 15기준으로', '3.8~3.9정도?', '작년 광고피알 3.7도 붙엇습니당', '확실하게 할라면 3.8넘는게..
# <  <EOS>
#
# > 이중전공 걱정 공대 수학 중학교 해내 모르 힘들 언어 배우 아니 걱정
# = 사회과학 계열해요~~!!', '음.. 나름 버틸만해요 족보도 있을거고 막 그렇게 어렵진않음
# <  <EOS>
#
# > 이중전공 변경 재학
# = 변경신청 1회만 가능하다고 학사편람에서 봤던 것 같아요!
# <  <EOS>
#
# > 소수 플러스 메이저 언어 이중전공 힘들 하나
# = 힘든것도 힘들고 도움도 안됨
# <  <EOS>
#
# > 영통 이중전공 학점 정도
# = 올해 미달나서 다 붙었을썰', '껄
# <  <EOS>
#
# > 학년 이중전공 변경 학년 성적 들어가
# = 2-1이면 ㅇㅇ
# < 네 그렇게 됩니다 <EOS>
#
# > 미디어 커뮤니케이션 이중전공 학점 정도 나오 만약 재수강 각인 과목 힘들
# = 3.5이상이면 가능하실듯 저도 3.78로 들어왔어요. 재수강각 과목말고 다른거 잘받으시면 괜찮아요! 저도 하나있어요', '아 감사합니당~
# <  <EOS>
#
# > 중외 17 학번 이중전공 추천
# = 아 그렇군요! 감사합니다!!
# <  <EOS>
#
# > 공대 이중전공 언어 힘들 언어 추천
# = 스페인어 했다가 힘들어서 영어로 바꾼 사람은 봤음
# <  <EOS>
#
# > 국제 통상 학과 이중전공 걱정
# = 저도요.... 진짜 국통법 때문에 미칠거 같네요 ,', '나두...', '국통 이중전공 기준이 어떻게되나요?? 많이 어렵나요?? 참고로 저는 글캠학생입니다', '학점 50퍼 시험 50퍼예요', '국통이중전공 원하는 새내기입니다. 어떻게 국통 이중전공할 수 있나요', '학점 3점대 후반 받으시고 학과 시험 잘보시면 됩니다', '국통은 따로시험본다는게 맞나요..?', '네', '시험 수학은 어떻게 준비해야 하나요? 영어는 어느정도 수준으로 나오나요?', '학과 시험
# <  <EOS>
#
# > 경영 후기 이중전공 신청 이중전공 떨어지 부전공 경영 후기 이중전공 경영 신청 경영 과목 수강 필수 아니 유리 어디 그렇
# = 부전공학점 다 채운다음 이중전공이랑 차이나는 전공점수 채워야되요', '한마디로 최소 9학기
# < 네 그렇게 가능합니다 <EOS>
#
# > 국제 학부 이중전공 정보
# = 반가워요 동지...!', '저요저요!', '저욤!', '오 친해져요!!', '님 국제학부 수업 어때요?', '그닥...국제학부에 엄청난 뜻이 있다면 추천이여
# <  <EOS>
#
# > 서울캠 네덜란드어 전공
# =
# <  <EOS>
#
# > 서울캠 경영학
# =
# <  <EOS>
#
# > 언어 공학 이중전공 서울 수업
# =  들을 수 있습니
# <  <EOS>
#
# > 편입 생도 이중전공
# =  필수는 아니지만 재학 연한 내에서 이중전공, 부전공 또는 전공 심화 과정을 이수할 수 있습니
# <  <EOS>
#
# > 네덜란드어 전공 캠퍼스
# = 캠퍼스에서 이수해야 합니
# < 네 그렇게 됩니다 <EOS>
#
# > 정치 외교학 이중전공 캠퍼스
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# <  <EOS>
#
# > 글캠 융합전공 신청
# =  가능합니다. 서울캠퍼스에서 이수해야 합니
# <  <EOS>
#
# > 융복 소프트웨어 전공 어디
# = 벌캠퍼스에서 수강하시면 됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 경제학 경제학 이중전공 신청
# = 학과는 경제학을 이중전공으로 이수할 수 없습니
# < 대학의 경제학과의 경우 이중(부)전공을 신청할 수 없습니 <EOS>
#
# > 경영 정보 학과 경영학 서울 이중전공
# = 정보학과는 경영학을 이중전공으로 이수할 수 없습니다. 부전공으로는 가능합니
# <  <EOS>
#
# > 국금 경영학 서울 이중전공
# = 금융학과는 경영학을 이중전공으로 이수할 수 없습니다. 부전공으로는 가능합니
# <  <EOS>
#
# > 학과 경영학 서울 이중전공
# = T학과는 경영학을 이중전공으로 이수할 수 없습니다. 부전공으로는 가능합니
# <  <EOS>
#
# > 국제 경영학 경영학 서울 이중전공
# = 경영학과는 경영학을 이중전공으로 이수할 수 없습니다. 부전공으로는 가능합니
# <  <EOS>
#
# > 영어 번역 학부 세부 전공 부전공 가능
# = SOL영어학전공만 선택가능합니
# < 학년별로 일정 티오 자리를 절삭함) <EOS>
#
# > 이중전공 필수 이수 학점
# = 15학번 이후는 42학점, 2007~2014학번인 경우 54학점을 이수해야 합니
# <  <EOS>
#
# > 부전공 필수 이수 학점
# =  관계 없이 21학점을 이수하셔야 합니
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 학년 시작
# = 년부터 시작이며, 배정시기는 2학년 진급 시로 합니
# < 네 그렇게 됩니다 <EOS>
#
# > 글캠 노어 이중전공 신청
# = 학과는 서울캠퍼스 전공을 신청할 수 없습니
# <  <EOS>
#
# > 융합전공 신청
# = 학계열 소속 학생은 신청할 수 없습니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 이중전공 언제 신청
# =  신청은 5월 말 또는 11월 말에 진행합니
# <  <EOS>
#
# > 이중전공 변경 기간
# = 전공 변경은 5월 초 또는 11월 초에 진행합니
# <  <EOS>
#
# > 자대 융복 소프트웨어 융합전공 신청
# = 학계열 소속 학생은 신청할 수 없습니
# < 네 그렇게 어렵진않음 <EOS>
#
# > 휴학 이중전공 변경
# = 기 이상 재학생 및 휴학생에 대해 이중전공 변경 신청이 가능합니
# <  <EOS>
#
# > 이중전공 어떻 신청
# = 정보시스템 -> 전공/교직관리 -> 이중/2전공/부전공 신청에서 신청하면 됩니
# <  <EOS>
#
# > 이중전공 배정 결과 어디
# = 정보시스템 -> 전공/교직관리 -> 이수중인 전공에서 확인할 수 있습니
# <  <EOS>
#
# > 이중전공 신청 정원 초과
# = 학점 이상자, 성적 순 우선 후 34학점 이하, 성적 순으로 배정합니다. 학번대별 여석이 없는 학과는 신청할 수 없습니
# <  <EOS>
#
# > 융합전공 부전공
# = 전공은 부전공으로 이수할 수 없습니
# < 캠퍼스에서 가능하나, 서울캠퍼스에서 7월에 부전공 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 이중전공 어디 전화
# = 종합지원센터(Tel: 031-330-4026)로 문의하면 됩니
# <  <EOS>
#
# > 경영학 바꾸 바꾸 재수강
# = 전공 변경 후 기존 전공 재수강은 불가능합니
# < 네 그렇게 됩니다 <EOS>
#
# > 후기 이중전공
# = 공 이수자가 정규 8학기 내에 제1전공 졸업학점(부전공 21학점 포함)을 모두 취득한 후, 1~2학기 추가 수학하여 해당 부전공의 이중전공화에 필요한 나머지 학점을 취득함으로써, 제 1전공과 이중전공 학위를 동시에 취득하는 제도입니
# <  <EOS>
#
# > 후기 이중전공 신청 자격
# = 공을 이수중인 7~8학기생을 대상으로 후기이중전공을 신청할 수 있습니
# <  <EOS>
#
# > 행정학 이중전공 캠퍼스
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# <  <EOS>
#
# > 언론 정보 이중전공 캠퍼스
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# <  <EOS>
#
# > 광고 랜딩 전공 서울캠
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# <  <EOS>
#
# > 전공 글캠
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# <  <EOS>
#
# > 어느캠 정치 외교학 전공 수업
# = 전공은 양 캠퍼스에서 가능하나, 부전공은 글로벌캠퍼스에서 가능합니
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 시험 합격 티오 신청
# = O.와 상관없이 이중전공 선발시험에 합격한 학생만이 이중전공 최종 선발대상자입니다. 시험에 합격하더라도 학점 3.0 미만인 경우 불합격될 수 있습니
# <  <EOS>
#
# > 인한 어느캠
# = 털인문한국학은 서울캠퍼스에서 이수해야 합니
# < 네 가능합니다 <EOS>
#
# > 이중전공 변경 기간 배정 다음 신청 가능
# =  학기에도 변경기간에 신청 가능합니
# <  <EOS>
#
# > 이중전공 바꾸
# = 전공은 한 번만 변경 가능합니
# <  <EOS>
#
# > 이중전공 결과
# = 20년 이중전공 배정결과는 6월 말에서 7월 초 예정입니
# <  <EOS>
#
# > 이중전공 필수
# = 07학번 이후 모든 학생은 이중전공, 부전공 또는 전공심화과정 중 1개의 과정을 선택하여 필수 이수하여야 합니
# <  <EOS>
#
# > 전공심화 부전공
# = 심화과정의 경우 부전공은 선택사항입니
# <  관계 없이 21학점을 이수하셔야 합니 <EOS>
#
# > 이중전공 학년 시작
# = 전공은 2학년부터 시작합니
# < 네 그렇게 됩니다 <EOS>
#
# > 부전공 학년
# = 공은 2학년부터 시작합니
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 학년 신청
# = 전공 배정시기는 2학년 진급 시로 합니
# < 네 그렇게 됩니다 <EOS>
#
# > 설캠 이중전공
# = 란드어, 스칸디나비아어, 베트남어, 터키.아제르바이잔어, 이란어, 몽골어, 경제학, 국제통상학, 국제학, 경영학, LD전공(2017학번부터), LT전공(2017학번부터), 외국어로서의한국어교육전공(입학전형 기준 외국인학생만 가능), 외국어로서의한국어통번역전공(2018학번부터)(입학전형 기준 외국인학생만 가능), BRICs, 언어와공학, 디지털인문한국학, 동북아외교통상, AI 융합전공이 있으며 양 캠퍼스 동시 개설 전공은 정치외교학, 행정학, 언론.정보, 광고.PR.브랜딩, 방송.영상.뉴미디어 전공이 있습니
# <  <EOS>
#
# > 부전공 설캠 전공
# = 란드어, 스칸디나비아어, 베트남어, 터키.아제르바이잔어, 이란어, 몽골어, 경제학, 국제통상학, 국제학, 경영학, LD전공(2017학번부터), LT전공(2017학번부터), 외국어로서의한국어교육전공(입학전형 기준 외국인학생만 가능), 외국어로서의한국어통번역전공(2018학번부터)(입학전형 기준 외국인학생만 가능)이 있습니
# <  관계 없이 21학점을 이수하셔야 합니 <EOS>
#
# > 네덜란드어 전공 캠퍼스
# = 캠퍼스에서 이수해야 합니
# < 네 그렇게 됩니다 <EOS>
#
# > 스칸디나비아 이중전공 설캠
# =  서울캠퍼스에서 이수하는 전공입니
# <  <EOS>
#
# > 융합전공 졸업 요건
# =  융합전공의 경우 졸업시험을 통과하여야 합니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 베트남어 이중전공 수업
# = 남어 이중전공의 경우 서울캠퍼스에서 이수해야 합니
# <  <EOS>
#
# > 이중전공 혁신 융합전공
# = 경제개발협력, 보험계리학, 학생주도의 개설학과가 있습니
# <  <EOS>
#
# > 융합전공 개설
# =  캠퍼스의 경우 BRICs, 언어와공학, 디지털인문한국학, 동북아외교통상, AI 융합전공이 융합전공으로 개설되어 있으며, 글로벌 캠퍼스의 경우 EU, 문화콘텐츠학, 국가리더(글로벌), 융복합소프트웨어, 세계문화예술경영이 융합전공으로 개설되어 있습니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 광역 특화 전공 신청
# = 특화전공의 경우 신규 신청이 불가능합니
# < 시험은 담당교수 재량입니다 국지대임에도 22학점을 수강하셨다면 아마 한국에서 다시 학과심사를 거쳐야 되서 떨어질 수도 있지만, 우수선발은 신청 시 100% 선발입니다 <EOS>
#
# > 정보 기록학 융합전공 신청 신청 가능
# = .기록학 융합전공은 신규 신청이 불가능합니
# < 전공교류는  <EOS>
#
# > 후기 이중전공 년도 시행
# = 14년부터 시행된 제도입니
# < 14년부터 시행된 제도입니 <EOS>
#
# > 부전공 이수 후기 이중전공 올리
# =  가능합니다. 정규 8학기 내 제1전공 졸업학점(부전공 21학점 포함)을 모두 취득한 경우 가능합니
# <  <EOS>
#
# > 후기 이중전공 선발 어디
# = 이중전공 선발의 경우 학과마다 상이하니 학과 홈페이지를 통해 확인하시면 됩니
# < 네 그렇게 가능합니다 <EOS>
#
# > 석사 연계 과정 후기 이중전공 신청
# = 석사 연계과정 이수자의 경우 후기이중전공을 신청할 수 없습니
# < 대학의 경제학과의 경우 이중(부)전공을 신청할 수 없습니 <EOS>
#
# > 후기 이중전공 신청
# = 이중전공의 경우 매년 4월 중 신청할 수 있습니
# <  <EOS>
#
# > 후기 이중전공 취소
# =  3/4선 이후부터 다음 학기 1/4선 이전까지만 가능하며, 졸업사정회의를 전후로 당학기 또는 다음 학기에 졸업할 수 있습니
# <  <EOS>
#
# > 후기 이중전공 전공 어디 연락
# = 종합지원센터(Tel: 031-330-4026)로 문의하면 됩니
# <  <EOS>
#
# > 언어 공학 전공 졸업 요건
# = 와공학전공의 경우 졸업시험을 통과하여야 졸업이 가능합니
# < 네 그렇게 됩니다 <EOS>
#
# > 문법 자선 신청
# = 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니
# < 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니 <EOS>
#
# > 언어 분석 위하 프로그래밍 자선 신청
# = 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 한국 근세사 자선 신청
# = 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 한국 철학사 자선 신청
# = 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 인문 지식 위키 수업 수강 자선 신청
# = 공 소속 단과대 교학 파트에 방문하여 이수구분 변경신청서를 작성하여야 이중전공 학점으로 처리됩니
# < 네 그렇게 들으셔도 됩니다 <EOS>
#
# > 이중전공 신청 자리
# = 전공 학과별/학번대별 여석이 없는 학과나 전공은 신청이 불가능합니
# <  <EOS>
#
# > 국제 경영학 이중전공 신청
# = 대학의 국제경영학과는 이중(부)전공을 신청할 수 없습니
# <  <EOS>
#
# > 경제학 이중전공 신청
# = 대학의 경제학과의 경우 이중(부)전공을 신청할 수 없습니
# < 대학의 경제학과의 경우 이중(부)전공을 신청할 수 없습니 <EOS>
#
# > 경영 정보 이중전공 가능
# = 대학의 경영정보학과의 경우 이중(부)전공을 신청할 수 없습니
# <  <EOS>
#
# > 편입 부전공 신청
# = 생도 부전공을 이수할 수 있습니다. 단 이수 시 졸업조건이 변경됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 중복 학과 이중전공 서울로 신청
# =  불가능합니
# <  <EOS>
#
# > 설캠이 바꾸 수업 재수강 못하
# =  이중전공 변경 이후에는 재수강이 불가능합니
# < 네 그렇게 됩니다 <EOS>
#
# > 이중전공 신청 기간 지나 추가 신청
# = 전공 신청기간 이후에는 추가 신청이 절대 불가능합니
# <  <EOS>
#
# > 이중전공 지망 지원 가능
# = 전공의 경우 2지망까지 지원가능합니
# <  <EOS>
#
# > 후기 이중전공 허가 발표
# =  초 홈페이지 공고예정입니
# <  <EOS>
#
# > 전공심화 신청
# = 과 7월 부전공 신청 기간에 신청하시면 됩니
# <  <EOS>
#
# > 부전공 신청
# = 과 7월에 신청하시면 됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 융합전공 지망 신청 가능
# =  융합전공의 경우 2지망으로 신청불가능합니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 전공 필수 과목 어디 보나
# =  학과 홈페이지에서 확인하시면 됩니
# < 네 그렇게 됩니다 <EOS>
#
# > 융합전공 신청 어떻
# =  융합전공 이중전공신청서를 작성하여 학생 소속 캠퍼스 학사종합지원센터에서 접수하시면 됩니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 군대 이중전공 신청
# =  2회째 학기 재학자로 수업일수 3/4선 이후 군입예정자도 신청하여야 합니
# <  <EOS>
#
# > 전공 필수 전공 이중전공 겹치
# = 학과 홈페이지를 통해 확인하시면 됩니
# <  <EOS>
#
# > 이중전공 신청 지망
# = 망 신청은 선택사항이므로 신청하지 않아도 됩니
# <  <EOS>
#
# > 이중전공 신청 확인 가능
# = 전공은 당해 학기를 기준으로 1지망 신청 내역 기준 학과별 신청인원 및 경쟁률을 실시간으로 조회가능합니
# <  <EOS>
#
# > 이중전공 신청 경쟁 확인
# = 전공은 당해 학기를 기준으로 1지망 신청 내역 기준 학과별 신청인원 및 경쟁률을 실시간으로 조회가능합니
# <  <EOS>
#
# > 이전 연도 이중전공 배정 결과 어디
# =  학번 경쟁률 및 기존 배정 결과는 공개하지 않습니
# <  <EOS>
#
# > 이중전공 예전 경쟁 어디 확인
# =  학번 경쟁률 및 기존 배정 결과는 공개하지 않습니
# < 저요', 'me~', '저요!', '저요', '저용!', '다들 잡으셨나요ㅠㅠㅠ', '과사에 연락해보니까 3월 3월 3월 그것도 넣으면 글을 연락해보니까 3월 감사합니다^^', '저거는 상공회의소 이외언어보는거에요 학사공지에 주요학사일정에 다나왔어요 봐야되는학과는 <EOS>
#
# > 지망 신청 지망 선발 인원 초과
# = 망 선발인원을 이미 초과해버린 경우 2지망으로 신청 시 배정해주지 않습니
# < 네 그렇게 됩니다 <EOS>
#
# > 설캠 이중전공 학과
# = 대학 각 학과(전공), 프랑스어과, 독일어과, 노어과, 스페인어과, 이탈리아어과, 포르투갈어과, 말레이.인도네시아어과, 아랍어과, 태국어과, 인도어과, 중국어대학 및 일본어대학 각 전공에 대해서는 글로벌캠퍼스 학생이 신청불가능합니
# <  <EOS>
#
# > 이중전공 변경 지망 신청 가능
# = 전공 변경 신청은 1지망만 신청 가능합니
# <  <EOS>
#
# > 전공 이중전공 신청 가능
# = 전공의 경우 2017학번부터 이중전공 신청이 가능합니
# <  <EOS>
#
# > 전공 이중전공 신청 가능
# = 전공의 경우 2017학번부터 이중전공 신청이 가능합니
# <  <EOS>
#
# > 학기 이중전공 변경 신청
# = 월 말에서 1월 초에 예정입니
# <  <EOS>
#
# > 글로벌 캠퍼스 개설 융합전공
# = 경제개발협력전공, 보험계리학전공, EU전공, 국가리더전공, 문화콘텐츠학전공, 세계문화예술경영전공, 융복합소프트웨어전공이 있습니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 휴학 후기 이중전공 신청 가능
# =  가능합니
# <  <EOS>
#
# > 융합전공 수강
# = 합전공 자료는 2020년 수강편람 26~43쪽을 참고하기 바랍니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 융합전공 캠퍼스
# = 융합전공은 2020년 현재 서울캠퍼스에서 개설 돼 있습니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 융합전공 캠퍼스
# = 융합전공은 2020년 현재 서울캠퍼스에서 수강 가능합니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 융합전공 부전공 이수 가능
# = 전공은 이중(제2)전공으로만 이수 가능합니다. 국가 리더 전공은 부전공도 가능합니
# < 캠퍼스에서 가능하나, 서울캠퍼스에서 7월에 부전공 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 광역 특화 전공 정보 기록학 전공 신청 가능
# = 특화전공, 정보기록학전공은 2020-1학기부터 폐지. 신규 신청 불가합니
# < 방학 중 하나일걸', '안높아도됨 그래도 3.5는 나와야해..', '과사 전화 <EOS>
#
# > 브릭스 전공 어디 개설
# = ICs(브릭스)전공은 서울 캠퍼스에 개설 돼 있습니
# < 네 그렇게 됩니다 <EOS>
#
# > 언어 공학 전공 어디 개설
# = 와 공학 전공은 서울 캠퍼스에 개설 돼 있습니다
# <  <EOS>
#
# > 융합전공
# =  이상의 학과(학부/전공)가 연계하여 개설한 전공으로, 이중전공으로만 이수 가능합니다. (국가리더전공은 부전공도 가능합니다
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 서울 캠퍼스 융합전공
# =  캠퍼스에서 수강할 수 있는 융합전공은 브릭스 전공, 동북아 외교 통상 전공(구 동북아 전공), 언어와 공학 전공, 디지털 인문 한국학 전공, AI융합전공이 있습니다
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 글로벌 캠퍼스 융합전공
# = 전공, 문화콘텐츠학 전공, 국가리더전공, 융복합소프트웨어 전공, 세계문화예술경영 전공이 있습니다
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 브릭스 전공 글로벌 캠퍼스
# = ICs(브릭스)전공은 서울 캠퍼스에서 수강 가능하며, 현재 글로벌 캠퍼스 강의는 폐지되었습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 브릭스 전공 펠로우 인정 학점
# = ICs펠로우십 10학점, 자선 8학점(최대 18학점)으로 최대 18학점이 인정됩니다
# < 네 그렇게 됩니다 <EOS>
#
# > 71 갔다오 학점 인정
# = 우십과 무관한 국내외 학점교류(인턴십, 7+1제도, 단기어학연수 등)는 BRICs 융합전공 학점으로 인정하지 않습니
# < 막학기가 어케 받음; 못받아요 추가학기 다녀도 못받음', '이번에는 4-1이고 내년이 4-2인데 못받나요??', '그건 받죠', '다음학기가 4-2면 가능합니다 <EOS>
#
# > 세계 문화 예술 경영 전공 졸업 요건
# =  시험 및 논문 중 택1 입니
# < 네 그렇게 됩니다 <EOS>
#
# > 문화콘텐츠 학전 졸업 학위 나오
# = 콘텐츠 학사 학위가 나옵니
# < 네 그렇게 됩니다 <EOS>
#
# > 문화콘텐츠 전공 문의 어디
# = 캠퍼스 대학원 글로벌문화콘텐츠학과(02-2173-293
# < 네 그렇게 됩니다 <EOS>
#
# > 융복 소프트웨어 전공의 필수 전공 무엇
# = 터프로그래밍1, 컴퓨터프로그래밍2, 자료구조, 알고리즘, 소프트웨어공학, 종합설계가 필수 이수 전공입니
# < 네 그렇게 됩니다 <EOS>
#
# > 공대 융복 소프트웨어 전공
# = 합소프트웨어 전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니
# < 네 그렇게 됩니다 <EOS>
#
# > 공대 융합전공 신청 가능
# = 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니
# < 서류라면 문제없습니다 <EOS>
#
# > 자대 융합전공 신청 가능
# = 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 혁신 융합전공 무엇
# = 이 스스로 교육과정을 구성하여 학교의 승인을 받은 후 전공을 이수하는 전공과정입니다. 2학년 이상의 학부생은 관심 분야의 전공교과과정(2개 전공 이상, 54학점 이상)을 편성하여 학사종합지원센터에 신청서를 제출하고, 이를 혁신융합전공으로 인정받으면 이중전공으로 이수 할 수 있습니다. 최종 승인을 받은 혁신융합전공 중 필수과목은 반드시 이수하여야 하며, 총 42학점 이상을 이수하여야 이중전공으로 인정받을 수 있습니다. 자세한 사항은 학사 공지 496번 글을 확인하시기 바랍니다
# < 융합전공은 공과대학, 자연과학대학을 제외한 인문계열 학생이 이수가능합니 <EOS>
#
# > 광역 특화 전공
# = 주도 CK-Ⅱ 사업의 일환으로 2015학년도부터 신설되는 ‘광역특화’ 융합전 공은 기존 단일 국가 단일 언어 차원의 외국학 교육을 ‘로컬리티(Locality)’라는 초국가 적 광역단위로 확대 심화시킨 국제지역대학만의 독창적인 이중전공 프로그램입니
# < 시험은 담당교수 재량입니다 <EOS>
#
# > 디지털 인문학 전공
# = 의 인문학적 전통과 문화에 대한 심층적 지식을 바탕으로 디지털 매체를 활용한 해외 송출과 쌍방향 소통이 가능한 지식통합형 인재를 길러내기 위한 융합전공으로 한국의 언어/문학, 사상, 역사에 대한 인문지식을 균형 있게 학습하고 이를 디지털 테 크놀로지를 활용하여 콘텐츠화 하는 방법론을 습득합니
# < 네 맞아요', '엠티 농활 체전 이런것두 포함인가요? ㅠㅠ', '농활은 아니고요 엠티랑 체전까지는 포함되요 쉽게 말하면 교수님 눈에 잘 띄면 됩니다 <EOS>
#
# > 디지털 문학 전공 연계 기초 과목
# = 철학사(철학과), 한국사입문(사학과) 또는 한국문화사(사학 부전공), KFL문법(언어인지과학과), 인문지식 위키(지식콘텐츠학부) 또는 디 지털시대의 텍스트와 지식(문화콘텐츠학융합전공), 한국현대사회와 문학(한국학과), 기 록의 조직화와 정보-문화 서비스(정보기록문화유산관리학 전공), 컴퓨터 프로그래밍 (융복합 소프트웨어 전공) 또는 언어분석을 위한 프로그래밍 (언어와 공학 전공) 외 기타 연계기초과목과 유사과목으로 주임교수가 인정한 과목이 있습니다
# < 네 그렇게 됩니다 <EOS>
#
# > 디지털 인문학 전공 연계 기초 과목 학점 인정 어떻
# = 신청 후 학사종합지원센터 단과대 교학파트(본인 1전공 소속 기준)에 방문하여 이수구분신청서를 작성해야 합니다
# < 네 그렇게 됩니다 <EOS>
#
# > 전공 졸업 요건
# = 형 종합시험으로 실시합니다
# < 네 그렇게 됩니다 <EOS>

# %%
new_pair = [['이중 전공 신청 경쟁률 확인', '']]

load_new_pair, load_new_source_vocab, load_new_target_vocab = preprocess(new_pair, SOURCE_MAX_LENGTH,
                                                              TARGET_MAX_LENGTH)
source_vocab_reload = concat_vocab(source_vocab, new_pair[0])

evaluate(load_new_pair, source_vocab_reload, load_target_vocab, enc, dec, TARGET_MAX_LENGTH)
# Out:
# reading corpus...
# Counting Words...
# source vocab size =  3815
# target vocab size =  29255
# > 이중 전공 신청 경쟁률 확인
# =
# < 본인의 졸업학점을 다 채우시면 됩니다 <EOS>
